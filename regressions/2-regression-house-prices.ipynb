# %% [markdown]
# # Regression With Tensorflow (House Prices)
# Let's predict some house prices

# %%
from __future__ import absolute_import, division, print_function

# %matplotlib inline

import pathlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Step 1 : Read Data

# %%
data_location = '/data/house-prices/house-sales-full.csv'
# data_location = 'https://elephantscale-public.s3.amazonaws.com/data/house-prices/house-sales-full.csv'

house_prices = pd.read_csv(data_location)
house_prices
# Out:
#        DocumentID      Date  SalePrice  PropertyID   PropertyType       ym  \
# 0               1   9/16/14     280000     1000102      Multiplex   9/1/14
# 1               2   6/16/06    1000000     1200013  Single Family   6/1/06
# 2               3   1/29/07     745000     1200019  Single Family   1/1/07
# 3               4   2/25/08     425000     2800016  Single Family   2/1/08
# 4               5   3/29/13     240000     2800024  Single Family   3/1/13
# ...           ...       ...        ...         ...            ...      ...
# 27058       27059  10/31/12     374000  9895000030      Townhouse  10/1/12
# 27059       27060   12/7/12     374000  9895000040      Townhouse  12/1/12
# 27060       27061    7/9/12     165000  9899200010  Single Family   7/1/12
# 27061       27062   5/26/06     315000  9900000355  Single Family   5/1/06
# 27062       27063    1/9/07     465000  9906000035  Single Family   1/1/07
#
#        zhvi_px  zhvi_idx  AdjSalePrice  NbrLivingUnits  ...  Bathrooms  \
# 0       405100      0.93    300,805.00               2  ...       3.00
# 1       404400      0.93  1,076,162.00               1  ...       3.75
# 2       425600      0.98    761,805.00               1  ...       1.75
# 3       418400      0.96    442,065.00               1  ...       3.75
# 4       351600      0.81    297,065.00               1  ...       1.75
# ...        ...       ...           ...             ...  ...        ...
# 27058   332400      0.76    489,665.00               1  ...       1.75
# 27059   339400      0.78    479,566.00               1  ...       1.75
# 27060   325300      0.75    220,744.00               1  ...       1.00
# 27061   400600      0.92    342,207.00               1  ...       2.00
# 27062   425600      0.98    475,489.00               1  ...       1.50
#
#        Bedrooms  BldgGrade  YrBuilt  YrRenovated  TrafficNoise  LandVal  \
# 0             6          7     1991            0             0    70000
# 1             4         10     2005            0             0   203000
# 2             4          8     1947            0             0   183000
# 3             5          7     1966            0             0   104000
# 4             4          7     1948            0             0   104000
# ...         ...        ...      ...          ...           ...      ...
# 27058         2          9     2011            0             0   147000
# 27059         2          9     2011            0             0   147000
# 27060         4          6     1971            0             0    92000
# 27061         3          7     1939            0             0   103000
# 27062         3          7     1928            0             0   311000
#
#        ImpsVal  ZipCode  NewConstruction
# 0       229000    98002            False
# 1       590000    98166             True
# 2       275000    98166            False
# 3       229000    98168            False
# 4       205000    98168            False
# ...        ...      ...              ...
# 27058   269000       -1            False
# 27059   269000       -1             True
# 27060   130000    98055            False
# 27061   212000    98166            False
# 27062   268000    98103            False
#
# [27063 rows x 23 columns]

# %% [markdown]
# ## Step 2 : Cleanup Data

# %%
print("original row count : ", house_prices.shape)
house_prices = house_prices.dropna()
print ("cleaned up row count : ", house_prices.shape)
# Out:
# original row count :  (27063, 23)
# cleaned up row count :  (27063, 23)

# %% [markdown]
# ## Step 3 : Exploratory Data Analysis (EDA)
# EDA will give us a sense of data.  It is highly recommended that you do this before learning.
#
# **==> Q : What is max number of bedrooms? :-)**

# %%
## get a summary of data
pd.options.display.float_format = '{:,.2f}'.format
house_prices.describe().T
# Out:
#                     count             mean              std          min  \
# DocumentID      27,063.00        13,532.00         7,812.56         1.00
# SalePrice       27,063.00       511,626.20       342,821.17     3,000.00
# PropertyID      27,063.00 4,680,324,882.08 2,896,350,979.15 1,000,102.00
# zhvi_px         27,063.00       390,750.58        37,024.46   311,600.00
# zhvi_idx        27,063.00             0.90             0.09         0.72
# AdjSalePrice    27,063.00       570,918.76       380,236.63     3,368.00
# NbrLivingUnits  27,063.00             1.02             0.15         1.00
# SqFtLot         27,063.00        10,997.68        28,110.66       494.00
# SqFtTotLiving   27,063.00         2,122.96           939.84       370.00
# SqFtFinBasement 27,063.00           275.30           428.71         0.00
# Bathrooms       27,063.00             2.26             0.77         0.00
# Bedrooms        27,063.00             3.38             0.90         0.00
# BldgGrade       27,063.00             7.78             1.18         3.00
# YrBuilt         27,063.00         1,977.09            30.92     1,900.00
# YrRenovated     27,063.00            86.73           407.32         0.00
# TrafficNoise    27,063.00             0.21             0.55         0.00
# LandVal         27,063.00       213,820.07       177,213.41         0.00
# ImpsVal         27,063.00       317,211.67       234,038.34         0.00
# ZipCode         27,063.00        82,223.04        36,106.67        -1.00
#
#                              25%              50%              75%  \
# DocumentID              6,766.50        13,532.00        20,297.50
# SalePrice             329,000.00       425,000.00       590,000.00
# PropertyID      2,213,000,057.50 3,972,900,140.00 7,504,001,385.00
# zhvi_px               357,100.00       400,600.00       421,200.00
# zhvi_idx                    0.82             0.92             0.97
# AdjSalePrice          366,918.50       475,664.00       655,061.00
# NbrLivingUnits              1.00             1.00             1.00
# SqFtLot                 4,257.50         6,636.00         9,450.00
# SqFtTotLiving           1,440.00         1,940.00         2,610.00
# SqFtFinBasement             0.00             0.00           510.00
# Bathrooms                   1.75             2.50             2.50
# Bedrooms                    3.00             3.00             4.00
# BldgGrade                   7.00             8.00             8.00
# YrBuilt                 1,954.00         1,986.00         2,006.00
# YrRenovated                 0.00             0.00             0.00
# TrafficNoise                0.00             0.00             0.00
# LandVal               105,000.00       172,000.00       258,000.00
# ImpsVal               183,000.00       261,000.00       380,000.00
# ZipCode                98,019.00        98,053.00        98,115.00
#
#                              max
# DocumentID             27,063.00
# SalePrice          11,000,000.00
# PropertyID      9,906,000,035.00
# zhvi_px               435,200.00
# zhvi_idx                    1.00
# AdjSalePrice       11,644,855.00
# NbrLivingUnits              5.00
# SqFtLot             1,024,068.00
# SqFtTotLiving          10,740.00
# SqFtFinBasement         3,500.00
# Bathrooms                   8.00
# Bedrooms                   33.00
# BldgGrade                  13.00
# YrBuilt                 2,016.00
# YrRenovated             2,016.00
# TrafficNoise                3.00
# LandVal             5,538,000.00
# ImpsVal             5,772,000.00
# ZipCode                98,354.00

# %% [markdown]
# ## Step 4: Remove Outliers
# As you can see we have a few outliers.
# Let's remove them by considering only houses with less than 5 BR

# %%
## TODO : commented out for now, 
##        uncomment during tuning phase

# house_prices = house_prices[house_prices['Bedrooms'] <= 5]
# house_prices

# %% [markdown]
# ## Step 5 : Choose Columns to consider
# Which attributes do you think are important in deciding SalePrice?

# %%
## TODO : Experiment with this, 
## select columns you think are important in determining SalePrice
input_columns = ['Bedrooms', 'Bathrooms', 'SqFtTotLiving', 'SqFtLot']
label_column = 'SalePrice'
# x = house_prices.loc[:, input_columns]
x = house_prices [input_columns]
y = house_prices[[label_column]]

print(x.head())
print ('--------')
print (y.head())
# Out:
#    Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 0         6       3.00           2400     9373
# 1         4       3.75           3764    20156
# 2         4       1.75           2060    26036
# 3         5       3.75           3200     8618
# 4         4       1.75           1720     8620
# --------
#    SalePrice
# 0     280000
# 1    1000000
# 2     745000
# 3     425000
# 4     240000

# %% [markdown]
# ## Step 6 :  Split data into train /test

# %%
from sklearn.model_selection import train_test_split

## split train/test = 80% / 20%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# backup
x_train_bak = x_train.copy(deep=True)
x_test_bak = x_test.copy(deep=True)

print ("x_train.shape : ", x_train.shape)
print ("y_train.shape : ", y_train.shape)
print ("x_test.shape : ", x_test.shape)
print ("y_test.shape : ", y_test.shape)
# Out:
# x_train.shape :  (21650, 4)
# y_train.shape :  (21650, 1)
# x_test.shape :  (5413, 4)
# y_test.shape :  (5413, 1)

# %% [markdown]
# ## Step 7 : Scale Data

# %%
## To turn off scaling, comment this cell out

# def my_scaler(df):
#     #return (df-df.min())/(df.max()-df.min())  ## this is min/max scaler
#     return (df - df.mean()) / df.std()

# print ("x_train: before and after")
# print(x_train_bak.head())
# x_train = my_scaler(x_train_bak)
# print(x_train.head())

# print ('=====')
# print ('x_test: before / after')
# print (x_test_bak.head())
# x_test = my_scaler (x_test_bak)
# print (x_test.head())

# %%
# Normalize the input features using the sklearn StandardScaler.
# This will set the mean to 0 and standard deviation to 1.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.fit_transform(x_test[x_test.columns])

print ("x_train: before and after")
print(x_train_bak.head())
print('----')
print(x_train.head())

print ('======')
print ('x_test: before / after')
print (x_test_bak.head())
print('---')
print (x_test.head())
# Out:
# x_train: before and after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225         3       1.75           1500    15600
# 7990          3       2.00           1640     7250
# 16579         2       1.00            770     6731
# 6926          3       1.75           1350     8742
# 10340         4       2.50           2370    10631
# ----
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225     -0.44      -0.67          -0.67     0.16
# 7990      -0.44      -0.34          -0.52    -0.13
# 16579     -1.58      -1.64          -1.44    -0.15
# 6926      -0.44      -0.67          -0.83    -0.08
# 10340      0.70       0.31           0.25    -0.01
# ======
# x_test: before / after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925          3       1.75           1350     8742
# 10580         5       3.00           2460     9975
# 13379         3       2.50           2260     5220
# 1132          2       1.50            830     1034
# 20942         5       1.75           2040     8040
# ---
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# /home/ubuntu/apps/anaconda/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ubuntu/apps/anaconda/envs/tf2/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/ubuntu/apps/anaconda/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/ubuntu/apps/anaconda/envs/tf2/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# ## Step 8:  Build a Model
#
# Build a 3 layer network
# - input (64 neurons)
# - hidden (64 neurons)
# - output (1 neuron)

# %%
input_dim = len(input_columns)
print ("input_dim : ", input_dim)
model = tf.keras.Sequential([
                # Input layer.. implicitly defined
                tf.keras.layers.Dense(units=64, activation='relu', input_shape=[input_dim], name="hidden_1"),
                tf.keras.layers.Dense(units=64, activation='relu', name="hidden_2"),
                tf.keras.layers.Dense(units=1, activation='linear', name="output_layer")
            ])

optimizer = tf.keras.optimizers.RMSprop(0.01)

model.compile(loss='mean_squared_error',
              optimizer=optimizer,
              metrics=['mean_absolute_error', 'mean_squared_error'])

print (model.summary())

tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# input_dim :  4
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_1 (Dense)             (None, 64)                320
# _________________________________________________________________
# hidden_2 (Dense)             (None, 64)                4160
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 4,545
# Trainable params: 4,545
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Step 9:  Train

# %%
# %%time

## TODO configure some of these
epochs = 100  ## experiment 100, 500, 1000

print ("training starting ...")
## TODO : to see training output set verbose=2
history = model.fit(x_train, y_train, epochs=epochs)

print ("training done.")
# Out:
# training starting ...
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 21650 samples
# Epoch 1/100
# 21650/21650 [==============================] - 0s 22us/sample - loss: 215408548044.5162 - mean_absolute_error: 335323.6250 - mean_squared_error: 215408508928.0000
# Epoch 2/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 64414235075.9789 - mean_absolute_error: 154012.0625 - mean_squared_error: 64414232576.0000
# Epoch 3/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 59030768273.4411 - mean_absolute_error: 145412.6875 - mean_squared_error: 59030773760.0000
# Epoch 4/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 57509891795.5636 - mean_absolute_error: 143031.7500 - mean_squared_error: 57509904384.0000
# Epoch 5/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 56553364858.2888 - mean_absolute_error: 141096.9531 - mean_squared_error: 56553369600.0000
# Epoch 6/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 55700196308.5805 - mean_absolute_error: 140072.3281 - mean_squared_error: 55700176896.0000
# Epoch 7/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 55174050290.7093 - mean_absolute_error: 138887.6406 - mean_squared_error: 55174098944.0000
# Epoch 8/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54921769485.9529 - mean_absolute_error: 138570.0156 - mean_squared_error: 54921764864.0000
# Epoch 9/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54637098328.6127 - mean_absolute_error: 138217.7031 - mean_squared_error: 54637109248.0000
# Epoch 10/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54474308642.5275 - mean_absolute_error: 137873.7188 - mean_squared_error: 54474313728.0000
# Epoch 11/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54324013545.2497 - mean_absolute_error: 137253.9844 - mean_squared_error: 54323994624.0000
# Epoch 12/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54184337785.6266 - mean_absolute_error: 137362.5000 - mean_squared_error: 54184333312.0000
# Epoch 13/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54242922431.6748 - mean_absolute_error: 137246.5469 - mean_squared_error: 54242914304.0000
# Epoch 14/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54152440075.1387 - mean_absolute_error: 136861.7812 - mean_squared_error: 54152450048.00000s - loss: 52905702440.8821 - mean_absolute_error: 135709.4219 - mean_squared_error: 52905680896.00
# Epoch 15/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54055723129.8394 - mean_absolute_error: 137091.9688 - mean_squared_error: 54055739392.0000
# Epoch 16/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53992238337.7737 - mean_absolute_error: 136828.7969 - mean_squared_error: 53992226816.0000
# Epoch 17/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53840341869.0927 - mean_absolute_error: 136780.6562 - mean_squared_error: 53840355328.0000
# Epoch 18/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53830924584.0850 - mean_absolute_error: 136646.2188 - mean_squared_error: 53830893568.0000
# Epoch 19/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53838356306.7004 - mean_absolute_error: 136452.2031 - mean_squared_error: 53838356480.0000
# Epoch 20/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53788528572.6478 - mean_absolute_error: 136680.5312 - mean_squared_error: 53788536832.0000
# Epoch 21/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53680434373.2323 - mean_absolute_error: 136385.5625 - mean_squared_error: 53680414720.0000
# Epoch 22/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53648653215.0393 - mean_absolute_error: 136300.9531 - mean_squared_error: 53648687104.0000
# Epoch 23/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53716365215.7014 - mean_absolute_error: 135986.7969 - mean_squared_error: 53716344832.0000
# Epoch 24/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53605580800.7568 - mean_absolute_error: 136017.0625 - mean_squared_error: 53605593088.0000
# Epoch 25/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53618913116.9168 - mean_absolute_error: 136007.8281 - mean_squared_error: 53618921472.0000
# Epoch 26/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53512518204.6832 - mean_absolute_error: 136079.5000 - mean_squared_error: 53512556544.0000
# Epoch 27/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53580006001.0893 - mean_absolute_error: 135919.2188 - mean_squared_error: 53580025856.0000
# Epoch 28/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53405430757.7969 - mean_absolute_error: 136032.7188 - mean_squared_error: 53405425664.0000
# Epoch 29/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53448063974.9321 - mean_absolute_error: 135761.7969 - mean_squared_error: 53448060928.0000
# Epoch 30/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53430571019.0677 - mean_absolute_error: 135704.3438 - mean_squared_error: 53430558720.0000
# Epoch 31/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53306666827.5111 - mean_absolute_error: 135575.2656 - mean_squared_error: 53306671104.0000
# Epoch 32/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53323727464.7649 - mean_absolute_error: 135760.5312 - mean_squared_error: 53323747328.0000
# Epoch 33/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53335708909.7194 - mean_absolute_error: 135397.7812 - mean_squared_error: 53335732224.0000
# Epoch 34/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53329629171.1350 - mean_absolute_error: 135195.0469 - mean_squared_error: 53329625088.0000
# Epoch 35/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53281827848.7974 - mean_absolute_error: 135149.3906 - mean_squared_error: 53281832960.0000
# Epoch 36/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53203861665.1913 - mean_absolute_error: 135104.4844 - mean_squared_error: 53203853312.0000
# Epoch 37/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53199823034.7322 - mean_absolute_error: 134940.8906 - mean_squared_error: 53199822848.0000
# Epoch 38/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53188847787.3131 - mean_absolute_error: 135036.3438 - mean_squared_error: 53188816896.0000
# Epoch 39/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53096024979.4986 - mean_absolute_error: 134878.1406 - mean_squared_error: 53096038400.0000
# Epoch 40/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53127788083.5074 - mean_absolute_error: 134883.2344 - mean_squared_error: 53127811072.0000
# Epoch 41/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53055509320.9570 - mean_absolute_error: 134647.0312 - mean_squared_error: 53055512576.0000
# Epoch 42/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53056586547.0108 - mean_absolute_error: 134504.4531 - mean_squared_error: 53056561152.0000
# Epoch 43/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53042706202.1321 - mean_absolute_error: 134605.1562 - mean_squared_error: 53042692096.0000
# Epoch 44/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53128119368.5550 - mean_absolute_error: 134534.0312 - mean_squared_error: 53128126464.0000
# Epoch 45/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52980305498.8593 - mean_absolute_error: 134534.2031 - mean_squared_error: 52980314112.0000
# Epoch 46/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53011317014.4902 - mean_absolute_error: 134442.1250 - mean_squared_error: 53011353600.0000
# Epoch 47/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53023253847.4775 - mean_absolute_error: 134245.0000 - mean_squared_error: 53023236096.0000
# Epoch 48/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52948668465.9466 - mean_absolute_error: 134544.4844 - mean_squared_error: 52948676608.0000
# Epoch 49/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 53005736030.2175 - mean_absolute_error: 134237.7656 - mean_squared_error: 53005713408.0000
# Epoch 50/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52945198681.5350 - mean_absolute_error: 134413.2188 - mean_squared_error: 52945235968.0000
# Epoch 51/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52826073289.1108 - mean_absolute_error: 134142.6250 - mean_squared_error: 52826087424.0000
# Epoch 52/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52993735402.3612 - mean_absolute_error: 134216.8594 - mean_squared_error: 52993728512.0000
# Epoch 53/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52984118210.7965 - mean_absolute_error: 134232.9844 - mean_squared_error: 52984131584.0000
# Epoch 54/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52833916885.6211 - mean_absolute_error: 134260.2031 - mean_squared_error: 52833898496.0000
# Epoch 55/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52891677796.9338 - mean_absolute_error: 134061.7969 - mean_squared_error: 52891656192.0000
# Epoch 56/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52817758936.1988 - mean_absolute_error: 134002.1094 - mean_squared_error: 52817764352.0000
# Epoch 57/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52890781334.2655 - mean_absolute_error: 134315.6719 - mean_squared_error: 52890775552.0000
# Epoch 58/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52827640696.0658 - mean_absolute_error: 133993.8281 - mean_squared_error: 52827631616.0000
# Epoch 59/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52893905070.8131 - mean_absolute_error: 134172.7969 - mean_squared_error: 52893904896.0000
# Epoch 60/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52842308133.3181 - mean_absolute_error: 134068.7344 - mean_squared_error: 52842299392.0000
# Epoch 61/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 52891524560.8440 - mean_absolute_error: 134010.7812 - mean_squared_error: 52891500544.0000
# Epoch 62/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52889520379.0574 - mean_absolute_error: 134118.5469 - mean_squared_error: 52889485312.0000
# Epoch 63/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52880777272.7575 - mean_absolute_error: 134152.5781 - mean_squared_error: 52880760832.0000
# Epoch 64/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52826034185.6488 - mean_absolute_error: 133925.2188 - mean_squared_error: 52826025984.0000
# Epoch 65/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52795813997.7312 - mean_absolute_error: 133876.6562 - mean_squared_error: 52795834368.0000
# Epoch 66/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52627712466.3575 - mean_absolute_error: 134309.9062 - mean_squared_error: 52627718144.0000
# Epoch 67/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52797644739.4587 - mean_absolute_error: 133709.2812 - mean_squared_error: 52797640704.0000
# Epoch 68/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52776660924.8370 - mean_absolute_error: 133982.0938 - mean_squared_error: 52776669184.0000
# Epoch 69/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52554321031.1775 - mean_absolute_error: 133981.2031 - mean_squared_error: 52554342400.0000
# Epoch 70/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52750990183.2277 - mean_absolute_error: 133973.0469 - mean_squared_error: 52750999552.0000
# Epoch 71/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52886242677.5590 - mean_absolute_error: 133984.3125 - mean_squared_error: 52886249472.0000
# Epoch 72/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52772784950.7946 - mean_absolute_error: 133984.2500 - mean_squared_error: 52772769792.0000
# Epoch 73/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52738866020.5790 - mean_absolute_error: 133879.4844 - mean_squared_error: 52738854912.0000
# Epoch 74/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52805901407.8256 - mean_absolute_error: 133916.5000 - mean_squared_error: 52805885952.0000
# Epoch 75/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52699273380.4076 - mean_absolute_error: 133912.3594 - mean_squared_error: 52699275264.0000
# Epoch 76/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52667610757.8058 - mean_absolute_error: 134033.7656 - mean_squared_error: 52667604992.0000
# Epoch 77/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52700429312.4730 - mean_absolute_error: 133906.0469 - mean_squared_error: 52700438528.0000
# Epoch 78/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52664871024.5691 - mean_absolute_error: 133712.9688 - mean_squared_error: 52664852480.0000
# Epoch 79/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52689026949.3092 - mean_absolute_error: 133855.0938 - mean_squared_error: 52689031168.0000
# Epoch 80/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52606429979.0781 - mean_absolute_error: 133871.7344 - mean_squared_error: 52606435328.0000
# Epoch 81/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52749918994.8482 - mean_absolute_error: 133798.1875 - mean_squared_error: 52749946880.0000
# Epoch 82/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52661619134.1140 - mean_absolute_error: 133541.2656 - mean_squared_error: 52661616640.0000
# Epoch 83/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52716812150.8360 - mean_absolute_error: 133691.4062 - mean_squared_error: 52716810240.0000
# Epoch 84/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52587098407.1390 - mean_absolute_error: 133795.1094 - mean_squared_error: 52587069440.0000
# Epoch 85/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52576406042.2503 - mean_absolute_error: 133969.2969 - mean_squared_error: 52576387072.0000
# Epoch 86/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52643127204.4312 - mean_absolute_error: 133839.5156 - mean_squared_error: 52643131392.0000
# Epoch 87/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52640820894.2115 - mean_absolute_error: 133574.6094 - mean_squared_error: 52640829440.0000
# Epoch 88/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52656451620.7032 - mean_absolute_error: 133686.5000 - mean_squared_error: 52656431104.0000
# Epoch 89/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52514198568.3924 - mean_absolute_error: 133716.6875 - mean_squared_error: 52514185216.0000
# Epoch 90/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52629618303.7517 - mean_absolute_error: 133596.0781 - mean_squared_error: 52629602304.0000
# Epoch 91/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52580698938.9569 - mean_absolute_error: 133590.0781 - mean_squared_error: 52580728832.0000
# Epoch 92/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52633217846.4163 - mean_absolute_error: 133615.3906 - mean_squared_error: 52633198592.0000
# Epoch 93/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52592055320.3111 - mean_absolute_error: 133612.6875 - mean_squared_error: 52592074752.0000
# Epoch 94/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52596679320.0628 - mean_absolute_error: 133570.3594 - mean_squared_error: 52596703232.0000
# Epoch 95/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52581083595.3574 - mean_absolute_error: 133788.1562 - mean_squared_error: 52581130240.0000
# Epoch 96/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52615022706.8393 - mean_absolute_error: 133518.6094 - mean_squared_error: 52615016448.0000
# Epoch 97/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52507902122.8401 - mean_absolute_error: 133655.5781 - mean_squared_error: 52507889664.0000
# Epoch 98/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52581465053.0941 - mean_absolute_error: 133602.9062 - mean_squared_error: 52581466112.0000
# Epoch 99/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52390064359.1922 - mean_absolute_error: 133563.4844 - mean_squared_error: 52390051840.0000
# Epoch 100/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 52498178680.4678 - mean_absolute_error: 133632.1250 - mean_squared_error: 52498157568.0000
# training done.
# CPU times: user 1min 6s, sys: 5.18 s, total: 1min 11s
# Wall time: 39.6 s

# %% [markdown]
# ## Step 10: History

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.history['mean_squared_error'], label='mse')
plt.plot(history.history['mean_absolute_error'], label='mae')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 11 : Evaluate Model

# %%
metric_names = model.metrics_names
print ("model metrics : " , metric_names)
metrics = model.evaluate(x_test, y_test, verbose=0)

for idx, metric in enumerate(metric_names):
    print ("Metric : {} = {:,.2f}".format (metric_names[idx], metrics[idx]))

# print("Testing set - {} : {:,.2f}".format(model.metrics_namesloss))
# print("Testing set Mean Abs Error: {:,.2f}".format(mae))
# print("Testing set Mean Squared Error: {:,.2f}".format(mse))
# Out:
# model metrics :  ['loss', 'mean_absolute_error', 'mean_squared_error']
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Metric : loss = 63,500,594,225.00
# Metric : mean_absolute_error = 132,827.00
# Metric : mean_squared_error = 63,500,599,296.00

# %% [markdown]
# ## Step 12: Predict

# %%
predictions = model.predict(x_test)
print (x_test)
print(predictions)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# ...         ...        ...            ...      ...
# 3818       0.66      -0.61          -0.22    -0.22
# 22803     -0.38       0.66           0.61    -0.03
# 20370     -0.38       0.34           0.04    -0.31
# 4536      -0.38       0.34           0.46    -0.26
# 10743      0.66       0.34           1.03    -0.17
#
# [5413 rows x 4 columns]
# [[327146.56]
#  [499883.34]
#  [504886.62]
#  ...
#  [517940.4 ]
#  [610211.9 ]
#  [664786.3 ]]

# %% [markdown]
# ## Step 13: Evalute prediction output
# Let's do a pd dataframe and do some plots

# %%
predictions_df = pd.DataFrame(x_test_bak)  # use the original one, not scaled
predictions_df['actual_price'] = y_test
predictions_df['predicted_price'] = predictions
predictions_df['error'] = predictions_df['actual_price'] - predictions_df['predicted_price'] 

pd.options.display.float_format = '{:,.2f}'.format
## print sample to see different data every time
predictions_df.sample(frac=0.1)
## or just print the first few
# predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 23323         3       2.50           2680     5539        459990
# 17670         3       2.00           1560     9216        875000
# 2018          4       2.50           2940     8308       1250000
# 16042         3       2.25           2020     9652        350000
# 18169         3       2.50           1920     9000        258000
# ...         ...        ...            ...      ...           ...
# 22700         4       2.25           2380     4876        785000
# 22009         3       1.00           1270     7500        105000
# 449           4       1.00           1340     5800        356000
# 25238         5       3.50           2960    12527        357500
# 15004         3       3.00           1320     1012        346000
#
#        predicted_price       error
# 23323       638,586.62 -178,596.62
# 17670       364,229.69  510,770.31
# 2018        624,227.00  625,773.00
# 16042       448,413.34  -98,413.34
# 18169       418,895.72 -160,895.72
# ...                ...         ...
# 22700       517,359.09  267,640.91
# 22009       331,212.38 -226,212.38
# 449         364,972.34   -8,972.34
# 25238       639,099.88 -281,599.88
# 15004       396,185.12  -50,185.12
#
# [541 rows x 7 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist (predictions_df['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## In the previous plot, outliers are skewing the results
## let's filter out the outliers.
## only consider predictions where the error is less than 100k (chosen randomly)

# %matplotlib inline
import matplotlib.pyplot as plt

predictions_df_filtered = predictions_df[predictions_df['error'].abs() < 100000]

plt.hist (predictions_df_filtered['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## which house we got really wrong?
print ("biggest error : ")
predictions_df.loc[predictions_df['error'].abs().idxmax()]
# Out:
# biggest error :
# Bedrooms                   6.00
# Bathrooms                  6.50
# SqFtTotLiving          7,560.00
# SqFtLot               44,000.00
# actual_price      11,000,000.00
# predicted_price    2,516,892.50
# error              8,483,107.50
# Name: 20114, dtype: float64

# %%
## which house we are spot on?
print ("lowest error")
predictions_df.loc[predictions_df['error'].abs().idxmin()]
# Out:
# lowest error
# Bedrooms                4.00
# Bathrooms               3.50
# SqFtTotLiving       2,390.00
# SqFtLot            16,202.00
# actual_price      551,000.00
# predicted_price   550,958.31
# error                  41.69
# Name: 19947, dtype: float64

# %% [markdown]
# ### How many house sales, we predicted within 5% ?
# Let's use 5% margin of error as our benchmark

# %%
predictions_df['error_percentage'] = predictions_df['error'].abs() * 100 / predictions_df['actual_price']
predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 6925          3       1.75           1350     8742        373300
# 10580         5       3.00           2460     9975        450000
# 13379         3       2.50           2260     5220        485000
# 1132          2       1.50            830     1034        219950
# 20942         5       1.75           2040     8040        310000
# ...         ...        ...            ...      ...           ...
# 3818          4       1.75           1890     4800        489200
# 22803         3       2.75           2660    10004        450000
# 20370         3       2.50           2130     2520        567000
# 4536          3       2.50           2520     3750        735000
# 10743         4       2.50           3060     6272        504000
#
#        predicted_price       error  error_percentage
# 6925        327,146.56   46,153.44             12.36
# 10580       499,883.34  -49,883.34             11.09
# 13379       504,886.62  -19,886.62              4.10
# 1132        347,117.97 -127,167.97             57.82
# 20942       423,360.16 -113,360.16             36.57
# ...                ...         ...               ...
# 3818        453,867.84   35,332.16              7.22
# 22803       649,974.75 -199,974.75             44.44
# 20370       517,940.41   49,059.59              8.65
# 4536        610,211.88  124,788.12             16.98
# 10743       664,786.31 -160,786.31             31.90
#
# [5413 rows x 8 columns]

# %%
benchmark = 5  # 5%

good_predictions = predictions_df[predictions_df['error_percentage'] <= benchmark]

good_predictions
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 13379         3       2.50           2260     5220        485000
# 23559         5       2.25           3070    11475        635000
# 9894          4       1.00           1130     4000        365000
# 23789         2       2.00           1300     2983        400749
# 13689         3       2.50           1970     9153        430000
# ...         ...        ...            ...      ...           ...
# 8562          2       1.50            980     1425        369950
# 8555          3       2.25           1980     2375        484940
# 19690         3       1.50           1280     2114        416500
# 121           3       1.50           1810     6550        425000
# 2092          2       1.50            910      976        346000
#
#        predicted_price      error  error_percentage
# 13379       504,886.62 -19,886.62              4.10
# 23559       609,174.06  25,825.94              4.07
# 9894        357,503.47   7,496.53              2.05
# 23789       387,295.50  13,453.50              3.36
# 13689       429,660.56     339.44              0.08
# ...                ...        ...               ...
# 8562        367,513.59   2,436.41              0.66
# 8555        495,453.66 -10,513.66              2.17
# 19690       401,942.44  14,557.56              3.50
# 121         430,103.16  -5,103.16              1.20
# 2092        362,056.28 -16,056.28              4.64
#
# [723 rows x 8 columns]

# %%
meeting_benchmark = good_predictions.shape[0] *100 / predictions_df.shape[0]

print ("number of predictions within benchmark error ({}%) are  =  {:,}  ({:.1f}% of total)".
       format (benchmark, good_predictions.shape[0], meeting_benchmark))
# Out:
# number of predictions within benchmark error (5%) are  =  723  (13.4% of total)

# %% [markdown]
# ## Step 14: Ideas to Try
# Now that we had done an 'end-to-end' regression implementation, lets tune our algorithm.
#
# **==> Q : What are some fo the things we can do to get a higher performance?**
#
# Here are some ideas to get you started
# - **Idea 1 : Any other inputs we can add?**
#   - In Step 5, add a couple more columns as input
#   - only choose numeric columns at this time
#   - Try adding 'LandVal'  as an input column.  Run again, did that improve the benchmark performance?
#   - What would be the implication of adding all the columns?
#
# - **Idea 2 : Remove outliers**
# As you noticed, we have quite a bit of outliers (remember the 33 bedroom house? :-).  Outliers tend to skew the results.  So let's remove them
#   - Step 4 : uncomment the cell.  Here we are filtering only houses that have less than 5 bedrooms
#
# - **Idea 3 : Increase epochs**
#   - In Step 10, increase epochs from 100 to 500 to 1000
#   - Notice the training time will increase
#   - do you get better results?  why or why not?
#
# - **Idea 4 : Build a Bigger network**
#   - In Step 8, we are setting up our network.  We are using 64 neurons
#   - Increase the number of neurons from 64 to 128
#   - Th
#   - Does the training time go up?
#   - Are you getting better accuracy?
#   - We can also add more layers and build a 'deeper' network.  More on this later
#
# - **Idea 5 : Need more data :-)**
# Most of the time, neural networks can yield better results if trained on more data
#
# - **Any other ideas?**
#
# #### Share your experiments with the class!
#
# **What is the best score you have gotten? :-)**

# %% [markdown]
# ## Final Step : Create the most compact code
# In this notebook we walked you through multiple steps for learning purposes.
# Now we are asking you to come up with **bare minimum** code to implement this neural net.
#
# ### Class Challenge :-)
# - Let's see who can come up with most compact code (fewest lines)
# - Create a new notebook, and start from scratch
# - Few hints
#   - no prints
#   - minimize comments
#   - no debug / exploration
#
# **Ready, set, go!**
#
# ### Our Answer
# [minimal solution file](2.5-regression-house-prices-minimal.ipynb)
