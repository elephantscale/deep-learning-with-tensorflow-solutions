# %% [markdown]
# # Regression With Tensorflow (House Prices)
# Let's predict some house prices

# %%
## Determine if we are running on google colab

try:
    import google.colab
    RUNNING_IN_COLAB = True
except:
    RUNNING_IN_COLAB = False

print ("Running in Google COLAB : ", RUNNING_IN_COLAB)
# Out:
# Running in Google COLAB :  False

# %%
from __future__ import absolute_import, division, print_function

# %matplotlib inline

import pathlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Step 1 : Read Data

# %%
data_location = '../data/house-prices/house-sales-full.csv'

if RUNNING_IN_COLAB:
    data_location = 'https://elephantscale-public.s3.amazonaws.com/data/house-prices/house-sales-full.csv'

house_prices = pd.read_csv(data_location)
house_prices
# Out:
#        DocumentID      Date  SalePrice  PropertyID   PropertyType       ym  \
# 0               1   9/16/14     280000     1000102      Multiplex   9/1/14
# 1               2   6/16/06    1000000     1200013  Single Family   6/1/06
# 2               3   1/29/07     745000     1200019  Single Family   1/1/07
# 3               4   2/25/08     425000     2800016  Single Family   2/1/08
# 4               5   3/29/13     240000     2800024  Single Family   3/1/13
# ...           ...       ...        ...         ...            ...      ...
# 27058       27059  10/31/12     374000  9895000030      Townhouse  10/1/12
# 27059       27060   12/7/12     374000  9895000040      Townhouse  12/1/12
# 27060       27061    7/9/12     165000  9899200010  Single Family   7/1/12
# 27061       27062   5/26/06     315000  9900000355  Single Family   5/1/06
# 27062       27063    1/9/07     465000  9906000035  Single Family   1/1/07
#
#        zhvi_px  zhvi_idx  AdjSalePrice  NbrLivingUnits  ...  Bathrooms  \
# 0       405100  0.930836      300805.0               2  ...       3.00
# 1       404400  0.929228     1076162.0               1  ...       3.75
# 2       425600  0.977941      761805.0               1  ...       1.75
# 3       418400  0.961397      442065.0               1  ...       3.75
# 4       351600  0.807904      297065.0               1  ...       1.75
# ...        ...       ...           ...             ...  ...        ...
# 27058   332400  0.763787      489665.0               1  ...       1.75
# 27059   339400  0.779871      479566.0               1  ...       1.75
# 27060   325300  0.747472      220744.0               1  ...       1.00
# 27061   400600  0.920496      342207.0               1  ...       2.00
# 27062   425600  0.977941      475489.0               1  ...       1.50
#
#        Bedrooms  BldgGrade  YrBuilt  YrRenovated  TrafficNoise  LandVal  \
# 0             6          7     1991            0             0    70000
# 1             4         10     2005            0             0   203000
# 2             4          8     1947            0             0   183000
# 3             5          7     1966            0             0   104000
# 4             4          7     1948            0             0   104000
# ...         ...        ...      ...          ...           ...      ...
# 27058         2          9     2011            0             0   147000
# 27059         2          9     2011            0             0   147000
# 27060         4          6     1971            0             0    92000
# 27061         3          7     1939            0             0   103000
# 27062         3          7     1928            0             0   311000
#
#        ImpsVal  ZipCode  NewConstruction
# 0       229000    98002            False
# 1       590000    98166             True
# 2       275000    98166            False
# 3       229000    98168            False
# 4       205000    98168            False
# ...        ...      ...              ...
# 27058   269000       -1            False
# 27059   269000       -1             True
# 27060   130000    98055            False
# 27061   212000    98166            False
# 27062   268000    98103            False
#
# [27063 rows x 23 columns]

# %% [markdown]
# ## Step 2 : Cleanup Data

# %%
print("original row count : ", house_prices.shape)
house_prices = house_prices.dropna()
print ("cleaned up row count : ", house_prices.shape)
# Out:
# original row count :  (27063, 23)
# cleaned up row count :  (27063, 23)

# %% [markdown]
# ## Step 3 : Exploratory Data Analysis (EDA)
# EDA will give us a sense of data.  It is highly recommended that you do this before learning.
#
# **==> Q : What is max number of bedrooms? :-)**

# %%
## get a summary of data
pd.options.display.float_format = '{:,.2f}'.format
house_prices.describe().T
# Out:
#                     count             mean              std          min  \
# DocumentID      27,063.00        13,532.00         7,812.56         1.00
# SalePrice       27,063.00       511,626.20       342,821.17     3,000.00
# PropertyID      27,063.00 4,680,324,882.08 2,896,350,979.15 1,000,102.00
# zhvi_px         27,063.00       390,750.58        37,024.46   311,600.00
# zhvi_idx        27,063.00             0.90             0.09         0.72
# AdjSalePrice    27,063.00       570,918.76       380,236.63     3,368.00
# NbrLivingUnits  27,063.00             1.02             0.15         1.00
# SqFtLot         27,063.00        10,997.68        28,110.66       494.00
# SqFtTotLiving   27,063.00         2,122.96           939.84       370.00
# SqFtFinBasement 27,063.00           275.30           428.71         0.00
# Bathrooms       27,063.00             2.26             0.77         0.00
# Bedrooms        27,063.00             3.38             0.90         0.00
# BldgGrade       27,063.00             7.78             1.18         3.00
# YrBuilt         27,063.00         1,977.09            30.92     1,900.00
# YrRenovated     27,063.00            86.73           407.32         0.00
# TrafficNoise    27,063.00             0.21             0.55         0.00
# LandVal         27,063.00       213,820.07       177,213.41         0.00
# ImpsVal         27,063.00       317,211.67       234,038.34         0.00
# ZipCode         27,063.00        82,223.04        36,106.67        -1.00
#
#                              25%              50%              75%  \
# DocumentID              6,766.50        13,532.00        20,297.50
# SalePrice             329,000.00       425,000.00       590,000.00
# PropertyID      2,213,000,057.50 3,972,900,140.00 7,504,001,385.00
# zhvi_px               357,100.00       400,600.00       421,200.00
# zhvi_idx                    0.82             0.92             0.97
# AdjSalePrice          366,918.50       475,664.00       655,061.00
# NbrLivingUnits              1.00             1.00             1.00
# SqFtLot                 4,257.50         6,636.00         9,450.00
# SqFtTotLiving           1,440.00         1,940.00         2,610.00
# SqFtFinBasement             0.00             0.00           510.00
# Bathrooms                   1.75             2.50             2.50
# Bedrooms                    3.00             3.00             4.00
# BldgGrade                   7.00             8.00             8.00
# YrBuilt                 1,954.00         1,986.00         2,006.00
# YrRenovated                 0.00             0.00             0.00
# TrafficNoise                0.00             0.00             0.00
# LandVal               105,000.00       172,000.00       258,000.00
# ImpsVal               183,000.00       261,000.00       380,000.00
# ZipCode                98,019.00        98,053.00        98,115.00
#
#                              max
# DocumentID             27,063.00
# SalePrice          11,000,000.00
# PropertyID      9,906,000,035.00
# zhvi_px               435,200.00
# zhvi_idx                    1.00
# AdjSalePrice       11,644,855.00
# NbrLivingUnits              5.00
# SqFtLot             1,024,068.00
# SqFtTotLiving          10,740.00
# SqFtFinBasement         3,500.00
# Bathrooms                   8.00
# Bedrooms                   33.00
# BldgGrade                  13.00
# YrBuilt                 2,016.00
# YrRenovated             2,016.00
# TrafficNoise                3.00
# LandVal             5,538,000.00
# ImpsVal             5,772,000.00
# ZipCode                98,354.00

# %% [markdown]
# ## Step 4: Remove Outliers
# As you can see we have a few outliers.
# Let's remove them by considering only houses with less than 5 BR

# %%
## TODO : commented out for now, 
##        uncomment during tuning phase

# house_prices = house_prices[house_prices['Bedrooms'] <= 5]
# house_prices

# %% [markdown]
# ## Step 5 : Choose Columns to consider
# Which attributes do you think are important in deciding SalePrice?

# %%
## TODO : Experiment with this, 
## select columns you think are important in determining SalePrice
input_columns = ['Bedrooms', 'Bathrooms', 'SqFtTotLiving', 'SqFtLot']
label_column = 'SalePrice'
# x = house_prices.loc[:, input_columns]
x = house_prices [input_columns]
y = house_prices[[label_column]]

print(x.head())
print ('--------')
print (y.head())
# Out:
#    Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 0         6       3.00           2400     9373
# 1         4       3.75           3764    20156
# 2         4       1.75           2060    26036
# 3         5       3.75           3200     8618
# 4         4       1.75           1720     8620
# --------
#    SalePrice
# 0     280000
# 1    1000000
# 2     745000
# 3     425000
# 4     240000

# %% [markdown]
# ## Step 6 :  Split data into train /test

# %%
from sklearn.model_selection import train_test_split

## split train/test = 80% / 20%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# backup
x_train_bak = x_train.copy(deep=True)
x_test_bak = x_test.copy(deep=True)

print ("x_train.shape : ", x_train.shape)
print ("y_train.shape : ", y_train.shape)
print ("x_test.shape : ", x_test.shape)
print ("y_test.shape : ", y_test.shape)
# Out:
# x_train.shape :  (21650, 4)
# y_train.shape :  (21650, 1)
# x_test.shape :  (5413, 4)
# y_test.shape :  (5413, 1)

# %% [markdown]
# ## Step 7 : Scale Data

# %%
## To turn off scaling, comment this cell out

# def my_scaler(df):
#     #return (df-df.min())/(df.max()-df.min())  ## this is min/max scaler
#     return (df - df.mean()) / df.std()

# print ("x_train: before and after")
# print(x_train_bak.head())
# x_train = my_scaler(x_train_bak)
# print(x_train.head())

# print ('=====')
# print ('x_test: before / after')
# print (x_test_bak.head())
# x_test = my_scaler (x_test_bak)
# print (x_test.head())

# %%
# Normalize the input features using the sklearn StandardScaler.
# This will set the mean to 0 and standard deviation to 1.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.fit_transform(x_test[x_test.columns])

print ("x_train: before and after")
print(x_train_bak.head())
print('----')
print(x_train.head())

print ('======')
print ('x_test: before / after')
print (x_test_bak.head())
print('---')
print (x_test.head())
# Out:
# x_train: before and after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225         3       1.75           1500    15600
# 7990          3       2.00           1640     7250
# 16579         2       1.00            770     6731
# 6926          3       1.75           1350     8742
# 10340         4       2.50           2370    10631
# ----
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225     -0.44      -0.67          -0.67     0.16
# 7990      -0.44      -0.34          -0.52    -0.13
# 16579     -1.58      -1.64          -1.44    -0.15
# 6926      -0.44      -0.67          -0.83    -0.08
# 10340      0.70       0.31           0.25    -0.01
# ======
# x_test: before / after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925          3       1.75           1350     8742
# 10580         5       3.00           2460     9975
# 13379         3       2.50           2260     5220
# 1132          2       1.50            830     1034
# 20942         5       1.75           2040     8040
# ---
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# /home/sujee/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/sujee/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/sujee/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/sujee/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# ## Step 8:  Build a Model
#
# Build a 3 layer network
# - input (64 neurons)
# - hidden (64 neurons)
# - output (1 neuron)

# %%
input_dim = len(input_columns)
print ("input_dim : ", input_dim)
model = tf.keras.Sequential([
                # Input layer.. implicitly defined
                tf.keras.layers.Dense(units=64, activation='relu', input_shape=[input_dim]),
                tf.keras.layers.Dense(units=64, activation='relu'),
                tf.keras.layers.Dense(units=1, activation='linear')
            ])

optimizer = tf.keras.optimizers.RMSprop(0.01)

model.compile(loss='mean_squared_error',
              optimizer=optimizer,
              metrics=['mean_absolute_error', 'mean_squared_error'])

print (model.summary())

tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# input_dim :  4
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,545
# Trainable params: 4,545
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Step 9:  Train

# %%
# %%time

## TODO configure some of these
epochs = 100  ## experiment 100, 500, 1000

print ("training starting ...")
## TODO : to see training output set verbose=2
history = model.fit(x_train, y_train, epochs=epochs)

print ("training done.")
# Out:
# training starting ...
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 21650 samples
# Epoch 1/100
# 21650/21650 [==============================] - 0s 20us/sample - loss: 208229468343.7051 - mean_absolute_error: 331306.5625 - mean_squared_error: 208229384192.0000
# Epoch 2/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 62661236961.1381 - mean_absolute_error: 151071.4844 - mean_squared_error: 62661267456.0000
# Epoch 3/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 57540906472.2091 - mean_absolute_error: 142201.7188 - mean_squared_error: 57540911104.0000
# Epoch 4/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 56002562503.3844 - mean_absolute_error: 140252.0469 - mean_squared_error: 56002580480.0000
# Epoch 5/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 55211048242.5851 - mean_absolute_error: 138988.9219 - mean_squared_error: 55211048960.0000
# Epoch 6/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 54856409024.0532 - mean_absolute_error: 138105.4844 - mean_squared_error: 54856429568.0000
# Epoch 7/100
# 21650/21650 [==============================] - 0s 18us/sample - loss: 54572903607.9889 - mean_absolute_error: 137930.7031 - mean_squared_error: 54572929024.0000
# Epoch 8/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 54408769265.0775 - mean_absolute_error: 137608.8281 - mean_squared_error: 54408765440.0000
# Epoch 9/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 54334013806.8427 - mean_absolute_error: 137451.9375 - mean_squared_error: 54334025728.0000
# Epoch 10/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 54205162780.4497 - mean_absolute_error: 137289.5000 - mean_squared_error: 54205169664.0000
# Epoch 11/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 54134158704.4508 - mean_absolute_error: 137111.4844 - mean_squared_error: 54134132736.0000
# Epoch 12/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 54092281916.9197 - mean_absolute_error: 137149.8438 - mean_squared_error: 54092279808.0000
# Epoch 13/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53989805465.1270 - mean_absolute_error: 136929.7812 - mean_squared_error: 53989773312.0000
# Epoch 14/100
# 21650/21650 [==============================] - 0s 21us/sample - loss: 54039789767.7864 - mean_absolute_error: 137017.0938 - mean_squared_error: 54039764992.0000
# Epoch 15/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53888367558.2019 - mean_absolute_error: 136770.3281 - mean_squared_error: 53888380928.0000
# Epoch 16/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53897464011.3811 - mean_absolute_error: 136781.7500 - mean_squared_error: 53897457664.0000
# Epoch 17/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53937287097.4315 - mean_absolute_error: 136448.2812 - mean_squared_error: 53937258496.0000
# Epoch 18/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53930645571.3522 - mean_absolute_error: 136345.2031 - mean_squared_error: 53930655744.0000
# Epoch 19/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53662740337.3495 - mean_absolute_error: 136429.4062 - mean_squared_error: 53662732288.0000
# Epoch 20/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53795188796.9197 - mean_absolute_error: 136095.3750 - mean_squared_error: 53795196928.0000
# Epoch 21/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53701884462.3047 - mean_absolute_error: 136258.8750 - mean_squared_error: 53701881856.0000
# Epoch 22/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53659671473.3909 - mean_absolute_error: 135756.0156 - mean_squared_error: 53659660288.0000
# Epoch 23/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53695049437.3070 - mean_absolute_error: 135847.6094 - mean_squared_error: 53695086592.0000
# Epoch 24/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53653151893.6506 - mean_absolute_error: 135886.1562 - mean_squared_error: 53653135360.0000
# Epoch 25/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53607850316.2206 - mean_absolute_error: 135665.0000 - mean_squared_error: 53607862272.0000
# Epoch 26/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53565376941.6543 - mean_absolute_error: 135616.0469 - mean_squared_error: 53565419520.0000
# Epoch 27/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53521476946.7477 - mean_absolute_error: 135471.9375 - mean_squared_error: 53521461248.0000
# Epoch 28/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53429000908.2797 - mean_absolute_error: 135399.1719 - mean_squared_error: 53429035008.0000
# Epoch 29/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53499098958.9166 - mean_absolute_error: 135330.2500 - mean_squared_error: 53499117568.0000
# Epoch 30/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53383930349.7903 - mean_absolute_error: 135190.9219 - mean_squared_error: 53383925760.0000
# Epoch 31/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53349247357.9780 - mean_absolute_error: 135074.8281 - mean_squared_error: 53349244928.0000
# Epoch 32/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53375665739.3456 - mean_absolute_error: 135186.6875 - mean_squared_error: 53375688704.0000
# Epoch 33/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53372654246.2522 - mean_absolute_error: 134980.8438 - mean_squared_error: 53372682240.0000
# Epoch 34/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53278078276.8894 - mean_absolute_error: 135140.8594 - mean_squared_error: 53278101504.0000
# Epoch 35/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53291716286.0904 - mean_absolute_error: 135090.7969 - mean_squared_error: 53291720704.0000
# Epoch 36/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53363343849.6281 - mean_absolute_error: 134750.2344 - mean_squared_error: 53363355648.0000
# Epoch 37/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53226405246.4510 - mean_absolute_error: 135009.2812 - mean_squared_error: 53226405888.00000s - loss: 53915421160.2882 - mean_absolute_error: 135287.5312 - mean_squared_error: 53915430912.000
# Epoch 38/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53066165846.7917 - mean_absolute_error: 134721.9375 - mean_squared_error: 53066162176.0000
# Epoch 39/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53233117250.4063 - mean_absolute_error: 134806.8750 - mean_squared_error: 53233123328.0000
# Epoch 40/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53237826374.8759 - mean_absolute_error: 134605.6562 - mean_squared_error: 53237813248.0000
# Epoch 41/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53157723038.4717 - mean_absolute_error: 134607.8438 - mean_squared_error: 53157691392.0000
# Epoch 42/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53149700552.7087 - mean_absolute_error: 134516.7031 - mean_squared_error: 53149704192.0000
# Epoch 43/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53121448030.4066 - mean_absolute_error: 134667.3594 - mean_squared_error: 53121417216.0000
# Epoch 44/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53093720353.9363 - mean_absolute_error: 134470.5156 - mean_squared_error: 53093699584.0000
# Epoch 45/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53061239814.7163 - mean_absolute_error: 134715.4688 - mean_squared_error: 53061238784.0000
# Epoch 46/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53229141582.2781 - mean_absolute_error: 134396.1406 - mean_squared_error: 53229146112.0000
# Epoch 47/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53132778417.3909 - mean_absolute_error: 134175.7969 - mean_squared_error: 53132779520.0000
# Epoch 48/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53101624366.0682 - mean_absolute_error: 134225.4844 - mean_squared_error: 53101617152.0000
# Epoch 49/100
# 21650/21650 [==============================] - 0s 19us/sample - loss: 53101294088.8447 - mean_absolute_error: 134487.2188 - mean_squared_error: 53101301760.0000
# Epoch 50/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 53075943734.6527 - mean_absolute_error: 134282.7656 - mean_squared_error: 53075963904.0000
# Epoch 51/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52984720000.0355 - mean_absolute_error: 134505.3594 - mean_squared_error: 52984700928.0000
# Epoch 52/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53078632173.1045 - mean_absolute_error: 134249.9062 - mean_squared_error: 53078593536.0000
# Epoch 53/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53016260965.1939 - mean_absolute_error: 134237.5312 - mean_squared_error: 53016281088.0000
# Epoch 54/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53114615170.9916 - mean_absolute_error: 134062.1094 - mean_squared_error: 53114630144.0000
# Epoch 55/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52996163416.1870 - mean_absolute_error: 134170.0781 - mean_squared_error: 52996157440.0000
# Epoch 56/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 53003749490.4610 - mean_absolute_error: 134358.1094 - mean_squared_error: 53003739136.0000
# Epoch 57/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52926481544.1234 - mean_absolute_error: 134290.5469 - mean_squared_error: 52926488576.0000
# Epoch 58/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52967516716.0344 - mean_absolute_error: 134307.9062 - mean_squared_error: 52967530496.0000
# Epoch 59/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52913506111.5921 - mean_absolute_error: 134177.6250 - mean_squared_error: 52913483776.0000
# Epoch 60/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52895073596.2339 - mean_absolute_error: 134324.3125 - mean_squared_error: 52895076352.0000
# Epoch 61/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52989906092.0698 - mean_absolute_error: 134065.1094 - mean_squared_error: 52989935616.0000
# Epoch 62/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52942061421.1872 - mean_absolute_error: 134023.1875 - mean_squared_error: 52942082048.0000
# Epoch 63/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52930534342.7695 - mean_absolute_error: 134178.3594 - mean_squared_error: 52930531328.0000
# Epoch 64/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52872656894.6757 - mean_absolute_error: 133983.5625 - mean_squared_error: 52872667136.0000
# Epoch 65/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52863375273.9178 - mean_absolute_error: 134130.8906 - mean_squared_error: 52863365120.0000
# Epoch 66/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52873929695.4590 - mean_absolute_error: 134160.7969 - mean_squared_error: 52873916416.0000
# Epoch 67/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52850467059.3005 - mean_absolute_error: 134283.7031 - mean_squared_error: 52850458624.0000
# Epoch 68/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52782960747.8393 - mean_absolute_error: 133950.0469 - mean_squared_error: 52782948352.0000
# Epoch 69/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52821422175.3526 - mean_absolute_error: 134047.7969 - mean_squared_error: 52821434368.0000
# Epoch 70/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52895128109.7371 - mean_absolute_error: 133939.9531 - mean_squared_error: 52895109120.0000
# Epoch 71/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52856933604.4490 - mean_absolute_error: 134070.8750 - mean_squared_error: 52856913920.0000
# Epoch 72/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52899341959.0356 - mean_absolute_error: 133832.7500 - mean_squared_error: 52899323904.0000
# Epoch 73/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 52667314087.0799 - mean_absolute_error: 134055.5938 - mean_squared_error: 52667334656.0000
# Epoch 74/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52834675890.3132 - mean_absolute_error: 133894.8125 - mean_squared_error: 52834656256.0000
# Epoch 75/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52886521653.7541 - mean_absolute_error: 133796.6250 - mean_squared_error: 52886503424.0000
# Epoch 76/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52797126505.9710 - mean_absolute_error: 133945.3906 - mean_squared_error: 52797108224.0000
# Epoch 77/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52704734954.6450 - mean_absolute_error: 133867.7656 - mean_squared_error: 52704722944.0000
# Epoch 78/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52630819819.7092 - mean_absolute_error: 134092.7500 - mean_squared_error: 52630839296.0000
# Epoch 79/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52811885736.8536 - mean_absolute_error: 133888.0000 - mean_squared_error: 52811866112.0000
# Epoch 80/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52651846213.7644 - mean_absolute_error: 133810.5938 - mean_squared_error: 52651823104.0000
# Epoch 81/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52772748698.3095 - mean_absolute_error: 133842.7188 - mean_squared_error: 52772769792.0000
# Epoch 82/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52718430070.0793 - mean_absolute_error: 133772.0938 - mean_squared_error: 52718428160.0000
# Epoch 83/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52676411464.6496 - mean_absolute_error: 133813.7500 - mean_squared_error: 52676423680.0000
# Epoch 84/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52673273480.6437 - mean_absolute_error: 133687.6875 - mean_squared_error: 52673277952.0000
# Epoch 85/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52599745382.9912 - mean_absolute_error: 133850.5312 - mean_squared_error: 52599734272.0000
# Epoch 86/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52672187781.0727 - mean_absolute_error: 133646.2656 - mean_squared_error: 52672204800.0000
# Epoch 87/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52636598610.2747 - mean_absolute_error: 133806.1094 - mean_squared_error: 52636610560.0000
# Epoch 88/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52625946188.6699 - mean_absolute_error: 133741.5000 - mean_squared_error: 52625960960.0000
# Epoch 89/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52650762751.9527 - mean_absolute_error: 133607.3125 - mean_squared_error: 52650799104.0000
# Epoch 90/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52575834662.9262 - mean_absolute_error: 133866.6719 - mean_squared_error: 52575866880.0000
# Epoch 91/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52620316915.3005 - mean_absolute_error: 133563.0000 - mean_squared_error: 52620304384.0000
# Epoch 92/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52645968392.5609 - mean_absolute_error: 133761.0469 - mean_squared_error: 52645990400.0000
# Epoch 93/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52497638905.8986 - mean_absolute_error: 133637.2656 - mean_squared_error: 52497625088.0000
# Epoch 94/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52554844580.9515 - mean_absolute_error: 133698.7969 - mean_squared_error: 52554821632.0000
# Epoch 95/100
# 21650/21650 [==============================] - 0s 17us/sample - loss: 52458308262.0630 - mean_absolute_error: 133728.9531 - mean_squared_error: 52458319872.0000
# Epoch 96/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52532860375.6076 - mean_absolute_error: 133475.5469 - mean_squared_error: 52532879360.0000
# Epoch 97/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52382902356.9471 - mean_absolute_error: 133628.2344 - mean_squared_error: 52382916608.0000
# Epoch 98/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52579734917.0727 - mean_absolute_error: 133561.7656 - mean_squared_error: 52579753984.0000
# Epoch 99/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52568371208.3244 - mean_absolute_error: 133571.5781 - mean_squared_error: 52568358912.0000
# Epoch 100/100
# 21650/21650 [==============================] - 0s 16us/sample - loss: 52332587348.7342 - mean_absolute_error: 133456.7188 - mean_squared_error: 52332584960.0000
# training done.
# CPU times: user 1min 2s, sys: 3.99 s, total: 1min 6s
# Wall time: 35.7 s

# %% [markdown]
# ## Step 10: History

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.history['mean_squared_error'], label='mse')
plt.plot(history.history['mean_absolute_error'], label='mae')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 11 : Evaluate Model

# %%
metric_names = model.metrics_names
print ("model metrics : " , metric_names)
metrics = model.evaluate(x_test, y_test, verbose=0)

for idx, metric in enumerate(metric_names):
    print ("Metric : {} = {:,.2f}".format (metric_names[idx], metrics[idx]))

# print("Testing set - {} : {:,.2f}".format(model.metrics_namesloss))
# print("Testing set Mean Abs Error: {:,.2f}".format(mae))
# print("Testing set Mean Squared Error: {:,.2f}".format(mse))
# Out:
# model metrics :  ['loss', 'mean_absolute_error', 'mean_squared_error']
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Metric : loss = 64,307,965,623.59
# Metric : mean_absolute_error = 137,413.28
# Metric : mean_squared_error = 64,307,953,664.00

# %% [markdown]
# ## Step 12: Predict

# %%
predictions = model.predict(x_test)
print (x_test)
print(predictions)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# ...         ...        ...            ...      ...
# 3818       0.66      -0.61          -0.22    -0.22
# 22803     -0.38       0.66           0.61    -0.03
# 20370     -0.38       0.34           0.04    -0.31
# 4536      -0.38       0.34           0.46    -0.26
# 10743      0.66       0.34           1.03    -0.17
#
# [5413 rows x 4 columns]
# [[326284.16]
#  [513590.62]
#  [526019.5 ]
#  ...
#  [536482.1 ]
#  [632179.2 ]
#  [705561.  ]]

# %% [markdown]
# ## Step 13: Evalute prediction output
# Let's do a pd dataframe and do some plots

# %%
predictions_df = pd.DataFrame(x_test_bak)  # use the original one, not scaled
predictions_df['actual_price'] = y_test
predictions_df['predicted_price'] = predictions
predictions_df['error'] = predictions_df['actual_price'] - predictions_df['predicted_price'] 

pd.options.display.float_format = '{:,.2f}'.format
## print sample to see different data every time
predictions_df.sample(frac=0.1)
## or just print the first few
# predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 11353         3       1.75           1460    81021        600000
# 21159         4       3.75           2970     7370        480000
# 14540         4       2.50           2140    17211        506500
# 8611          2       1.50            950      865        327000
# 808           5       2.75           3230    48505        789000
# ...         ...        ...            ...      ...           ...
# 4558          3       1.00           1460     8305        376500
# 7222          3       2.00           1700     4600        399000
# 10391         3       2.25           1760     2914        299950
# 153           5       4.00           4610    17584       1140000
# 426           4       3.75           3160     9525       1127555
#
#        predicted_price       error
# 11353       357,324.66  242,675.34
# 21159       797,660.56 -317,660.56
# 14540       447,756.78   58,743.22
# 8611        362,960.66  -35,960.66
# 808         674,563.88  114,436.12
# ...                ...         ...
# 4558        348,346.72   28,153.28
# 7222        430,106.50  -31,106.50
# 10391       450,593.97 -150,643.97
# 153       1,357,961.88 -217,961.88
# 426         861,997.44  265,557.56
#
# [541 rows x 7 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist (predictions_df['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## In the previous plot, outliers are skewing the results
## let's filter out the outliers.
## only consider predictions where the error is less than 100k (chosen randomly)

# %matplotlib inline
import matplotlib.pyplot as plt

predictions_df_filtered = predictions_df[predictions_df['error'].abs() < 100000]

plt.hist (predictions_df_filtered['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## which house we got really wrong?
print ("biggest error : ")
predictions_df.loc[predictions_df['error'].abs().idxmax()]
# Out:
# biggest error :
# Bedrooms                   6.00
# Bathrooms                  6.50
# SqFtTotLiving          7,560.00
# SqFtLot               44,000.00
# actual_price      11,000,000.00
# predicted_price    2,731,253.50
# error              8,268,746.50
# Name: 20114, dtype: float64

# %%
## which house we are spot on?
print ("lowest error")
predictions_df.loc[predictions_df['error'].abs().idxmin()]
# Out:
# lowest error
# Bedrooms                3.00
# Bathrooms               2.00
# SqFtTotLiving       1,090.00
# SqFtLot             7,350.00
# actual_price      280,000.00
# predicted_price   280,012.12
# error                 -12.12
# Name: 5366, dtype: float64

# %% [markdown]
# ### How many house sales, we predicted within 5% ?
# Let's use 5% margin of error as our benchmark

# %%
predictions_df['error_percentage'] = predictions_df['error'].abs() * 100 / predictions_df['actual_price']
predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 6925          3       1.75           1350     8742        373300
# 10580         5       3.00           2460     9975        450000
# 13379         3       2.50           2260     5220        485000
# 1132          2       1.50            830     1034        219950
# 20942         5       1.75           2040     8040        310000
# ...         ...        ...            ...      ...           ...
# 3818          4       1.75           1890     4800        489200
# 22803         3       2.75           2660    10004        450000
# 20370         3       2.50           2130     2520        567000
# 4536          3       2.50           2520     3750        735000
# 10743         4       2.50           3060     6272        504000
#
#        predicted_price       error  error_percentage
# 6925        326,284.16   47,015.84             12.59
# 10580       513,590.62  -63,590.62             14.13
# 13379       526,019.50  -41,019.50              8.46
# 1132        337,905.31 -117,955.31             53.63
# 20942       427,183.69 -117,183.69             37.80
# ...                ...         ...               ...
# 3818        456,941.66   32,258.34              6.59
# 22803       676,990.50 -226,990.50             50.44
# 20370       536,482.12   30,517.88              5.38
# 4536        632,179.19  102,820.81             13.99
# 10743       705,561.00 -201,561.00             39.99
#
# [5413 rows x 8 columns]

# %%
benchmark = 5  # 5%

good_predictions = predictions_df[predictions_df['error_percentage'] <= benchmark]

good_predictions
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 23559         5       2.25           3070    11475        635000
# 23789         2       2.00           1300     2983        400749
# 13689         3       2.50           1970     9153        430000
# 151           6       3.50           3850     5591        899950
# 11961         3       2.50           1420     2581        391000
# ...         ...        ...            ...      ...           ...
# 8562          2       1.50            980     1425        369950
# 8555          3       2.25           1980     2375        484940
# 19690         3       1.50           1280     2114        416500
# 121           3       1.50           1810     6550        425000
# 2092          2       1.50            910      976        346000
#
#        predicted_price      error  error_percentage
# 23559       634,227.19     772.81              0.12
# 23789       392,715.59   8,033.41              2.00
# 13689       444,578.28 -14,578.28              3.39
# 151         902,590.06  -2,640.06              0.29
# 11961       376,231.38  14,768.62              3.78
# ...                ...        ...               ...
# 8562        360,454.38   9,495.62              2.57
# 8555        505,280.09 -20,340.09              4.19
# 19690       395,817.97  20,682.03              4.97
# 121         436,626.59 -11,626.59              2.74
# 2092        353,812.81  -7,812.81              2.26
#
# [703 rows x 8 columns]

# %%
meeting_benchmark = good_predictions.shape[0] *100 / predictions_df.shape[0]

print ("number of predictions within benchmark error ({}%) are  =  {:,}  ({:.1f}% of total)".
       format (benchmark, good_predictions.shape[0], meeting_benchmark))
# Out:
# number of predictions within benchmark error (5%) are  =  703  (13.0% of total)

# %% [markdown]
# ## Step 14: Ideas to Try
# Now that we had done an 'end-to-end' regression implementation, lets tune our algorithm.
#
# **==> Q : What are some fo the things we can do to get a higher performance?**
#
# Here are some ideas to get you started
# - **Idea 1 : Any other inputs we can add?**
#   - In Step 5, add a couple more columns as input
#   - only choose numeric columns at this time
#   - Try adding 'LandVal'  as an input column.  Run again, did that improve the benchmark performance?
#   - What would be the implication of adding all the columns?
#
# - **Idea 2 : Remove outliers**
# As you noticed, we have quite a bit of outliers (remember the 33 bedroom house? :-).  Outliers tend to skew the results.  So let's remove them
#   - Step 4 : uncomment the cell.  Here we are filtering only houses that have less than 5 bedrooms
#
# - **Idea 3 : Increase epochs**
#   - In Step 10, increase epochs from 100 to 500 to 1000
#   - Notice the training time will increase
#   - do you get better results?  why or why not?
#
# - **Idea 4 : Build a Bigger network**
#   - In Step 8, we are setting up our network.  We are using 64 neurons
#   - Increase the number of neurons from 64 to 128
#   - Th
#   - Does the training time go up?
#   - Are you getting better accuracy?
#   - We can also add more layers and build a 'deeper' network.  More on this later
#
# - **Idea 5 : Need more data :-)**
# Most of the time, neural networks can yield better results if trained on more data
#
# - **Any other ideas?**
#
# #### Share your experiments with the class!
#
# **What is the best score you have gotten? :-)**

# %% [markdown]
# ## Final Step : Create the most compact code
# In this notebook we walked you through multiple steps for learning purposes.
# Now we are asking you to come up with **bare minimum** code to implement this neural net.
#
# ### Class Challenge :-)
# - Let's see who can come up with most compact code (fewest lines)
# - Create a new notebook, and start from scratch
# - Few hints
#   - no prints
#   - minimize comments
#   - no debug / exploration
#
# **Ready, set, go!**
#
# ### Our Answer
# [minimal solution file](2.5-regression-house-prices-minimal.ipynb)
