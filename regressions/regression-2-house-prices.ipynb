# %% [markdown]
# # Regression With Tensorflow (House Prices)
# Let's predict some house prices

# %%
## Determine if we are running on google colab

try:
    import google.colab
    RUNNING_IN_COLAB = True
except:
    RUNNING_IN_COLAB = False

print ("Running in Google COLAB : ", RUNNING_IN_COLAB)

# %%
from __future__ import absolute_import, division, print_function

# %matplotlib inline

import pathlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Step 1 : Read Data

# %%
data_location = '../data/house-prices/house-sales-full.csv'

if RUNNING_IN_COLAB:
    data_location = 'https://elephantscale-public.s3.amazonaws.com/data/house-prices/house-sales-full.csv'

house_prices = pd.read_csv(data_location)
house_prices
# Out:
#        DocumentID      Date  SalePrice  PropertyID   PropertyType       ym  \
# 0               1   9/16/14     280000     1000102      Multiplex   9/1/14
# 1               2   6/16/06    1000000     1200013  Single Family   6/1/06
# 2               3   1/29/07     745000     1200019  Single Family   1/1/07
# 3               4   2/25/08     425000     2800016  Single Family   2/1/08
# 4               5   3/29/13     240000     2800024  Single Family   3/1/13
# ...           ...       ...        ...         ...            ...      ...
# 27058       27059  10/31/12     374000  9895000030      Townhouse  10/1/12
# 27059       27060   12/7/12     374000  9895000040      Townhouse  12/1/12
# 27060       27061    7/9/12     165000  9899200010  Single Family   7/1/12
# 27061       27062   5/26/06     315000  9900000355  Single Family   5/1/06
# 27062       27063    1/9/07     465000  9906000035  Single Family   1/1/07
#
#        zhvi_px  zhvi_idx  AdjSalePrice  NbrLivingUnits  ...  Bathrooms  \
# 0       405100  0.930836      300805.0               2  ...       3.00
# 1       404400  0.929228     1076162.0               1  ...       3.75
# 2       425600  0.977941      761805.0               1  ...       1.75
# 3       418400  0.961397      442065.0               1  ...       3.75
# 4       351600  0.807904      297065.0               1  ...       1.75
# ...        ...       ...           ...             ...  ...        ...
# 27058   332400  0.763787      489665.0               1  ...       1.75
# 27059   339400  0.779871      479566.0               1  ...       1.75
# 27060   325300  0.747472      220744.0               1  ...       1.00
# 27061   400600  0.920496      342207.0               1  ...       2.00
# 27062   425600  0.977941      475489.0               1  ...       1.50
#
#        Bedrooms  BldgGrade  YrBuilt  YrRenovated  TrafficNoise  LandVal  \
# 0             6          7     1991            0             0    70000
# 1             4         10     2005            0             0   203000
# 2             4          8     1947            0             0   183000
# 3             5          7     1966            0             0   104000
# 4             4          7     1948            0             0   104000
# ...         ...        ...      ...          ...           ...      ...
# 27058         2          9     2011            0             0   147000
# 27059         2          9     2011            0             0   147000
# 27060         4          6     1971            0             0    92000
# 27061         3          7     1939            0             0   103000
# 27062         3          7     1928            0             0   311000
#
#        ImpsVal  ZipCode  NewConstruction
# 0       229000    98002            False
# 1       590000    98166             True
# 2       275000    98166            False
# 3       229000    98168            False
# 4       205000    98168            False
# ...        ...      ...              ...
# 27058   269000       -1            False
# 27059   269000       -1             True
# 27060   130000    98055            False
# 27061   212000    98166            False
# 27062   268000    98103            False
#
# [27063 rows x 23 columns]

# %% [markdown]
# ## Step 2 : Cleanup Data

# %%
print("original row count : ", house_prices.shape)
house_prices = house_prices.dropna()
print ("cleaned up row count : ", house_prices.shape)
# Out:
# original row count :  (27063, 23)
# cleaned up row count :  (27063, 23)

# %% [markdown]
# ## Step 3 : Exploratory Data Analysis (EDA)
# EDA will give us a sense of data.  It is highly recommended that you do this before learning.
#
# **==> Q : What is max number of bedrooms? :-)**

# %%
## get a summary of data
pd.options.display.float_format = '{:,.2f}'.format
house_prices.describe().T
# Out:
#                     count             mean              std          min  \
# DocumentID      27,063.00        13,532.00         7,812.56         1.00
# SalePrice       27,063.00       511,626.20       342,821.17     3,000.00
# PropertyID      27,063.00 4,680,324,882.08 2,896,350,979.15 1,000,102.00
# zhvi_px         27,063.00       390,750.58        37,024.46   311,600.00
# zhvi_idx        27,063.00             0.90             0.09         0.72
# AdjSalePrice    27,063.00       570,918.76       380,236.63     3,368.00
# NbrLivingUnits  27,063.00             1.02             0.15         1.00
# SqFtLot         27,063.00        10,997.68        28,110.66       494.00
# SqFtTotLiving   27,063.00         2,122.96           939.84       370.00
# SqFtFinBasement 27,063.00           275.30           428.71         0.00
# Bathrooms       27,063.00             2.26             0.77         0.00
# Bedrooms        27,063.00             3.38             0.90         0.00
# BldgGrade       27,063.00             7.78             1.18         3.00
# YrBuilt         27,063.00         1,977.09            30.92     1,900.00
# YrRenovated     27,063.00            86.73           407.32         0.00
# TrafficNoise    27,063.00             0.21             0.55         0.00
# LandVal         27,063.00       213,820.07       177,213.41         0.00
# ImpsVal         27,063.00       317,211.67       234,038.34         0.00
# ZipCode         27,063.00        82,223.04        36,106.67        -1.00
#
#                              25%              50%              75%  \
# DocumentID              6,766.50        13,532.00        20,297.50
# SalePrice             329,000.00       425,000.00       590,000.00
# PropertyID      2,213,000,057.50 3,972,900,140.00 7,504,001,385.00
# zhvi_px               357,100.00       400,600.00       421,200.00
# zhvi_idx                    0.82             0.92             0.97
# AdjSalePrice          366,918.50       475,664.00       655,061.00
# NbrLivingUnits              1.00             1.00             1.00
# SqFtLot                 4,257.50         6,636.00         9,450.00
# SqFtTotLiving           1,440.00         1,940.00         2,610.00
# SqFtFinBasement             0.00             0.00           510.00
# Bathrooms                   1.75             2.50             2.50
# Bedrooms                    3.00             3.00             4.00
# BldgGrade                   7.00             8.00             8.00
# YrBuilt                 1,954.00         1,986.00         2,006.00
# YrRenovated                 0.00             0.00             0.00
# TrafficNoise                0.00             0.00             0.00
# LandVal               105,000.00       172,000.00       258,000.00
# ImpsVal               183,000.00       261,000.00       380,000.00
# ZipCode                98,019.00        98,053.00        98,115.00
#
#                              max
# DocumentID             27,063.00
# SalePrice          11,000,000.00
# PropertyID      9,906,000,035.00
# zhvi_px               435,200.00
# zhvi_idx                    1.00
# AdjSalePrice       11,644,855.00
# NbrLivingUnits              5.00
# SqFtLot             1,024,068.00
# SqFtTotLiving          10,740.00
# SqFtFinBasement         3,500.00
# Bathrooms                   8.00
# Bedrooms                   33.00
# BldgGrade                  13.00
# YrBuilt                 2,016.00
# YrRenovated             2,016.00
# TrafficNoise                3.00
# LandVal             5,538,000.00
# ImpsVal             5,772,000.00
# ZipCode                98,354.00

# %% [markdown]
# ## Step 4 : Choose Columns to consider
# Which attributes do you think are important in deciding SalePrice?

# %%
input_columns = ['Bedrooms', 'Bathrooms', 'SqFtTotLiving', 'SqFtLot']
label_column = 'SalePrice'

# %% [markdown]
# ## Step 5: Remove Outliers
# As you can see we have a few outliers.
# Let's remove them by considering only houses with less than 5 BR

# %%
house_prices[input_columns].hist(figsize=(20,10));

# %%
## TODO : commented out for now, 
##        uncomment during tuning phase

# house_prices = house_prices[house_prices['Bedrooms'] <= 5]
# house_prices
# house_prices[input_columns].hist(figsize=(20,10));

# %%
## TODO : Experiment with this, 
## select columns you think are important in determining SalePrice

# x = house_prices.loc[:, input_columns]
x = house_prices [input_columns]
y = house_prices[[label_column]]

print(x.head())
print ('--------')
print (y.head())
# Out:
#    Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 0         6       3.00           2400     9373
# 1         4       3.75           3764    20156
# 2         4       1.75           2060    26036
# 3         5       3.75           3200     8618
# 4         4       1.75           1720     8620
# --------
#    SalePrice
# 0     280000
# 1    1000000
# 2     745000
# 3     425000
# 4     240000

# %% [markdown]
# ## Step 6 :  Split data into train /test

# %%
from sklearn.model_selection import train_test_split

## split train/test = 80% / 20%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# backup
x_train_bak = x_train.copy(deep=True)
x_test_bak = x_test.copy(deep=True)

print ("x_train.shape : ", x_train.shape)
print ("y_train.shape : ", y_train.shape)
print ("x_test.shape : ", x_test.shape)
print ("y_test.shape : ", y_test.shape)
# Out:
# x_train.shape :  (21650, 4)
# y_train.shape :  (21650, 1)
# x_test.shape :  (5413, 4)
# y_test.shape :  (5413, 1)

# %% [markdown]
# ## Step 7 : Scale Data

# %%
## To turn off scaling, comment this cell out

# def my_scaler(df):
#     #return (df-df.min())/(df.max()-df.min())  ## this is min/max scaler
#     return (df - df.mean()) / df.std()

# print ("x_train: before and after")
# print(x_train_bak.head())
# x_train = my_scaler(x_train_bak)
# print(x_train.head())

# print ('=====')
# print ('x_test: before / after')
# print (x_test_bak.head())
# x_test = my_scaler (x_test_bak)
# print (x_test.head())

# %%
# Normalize the input features using the sklearn StandardScaler.
# This will set the mean to 0 and standard deviation to 1.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.fit_transform(x_test[x_test.columns])

print ("x_train: before and after")
print(x_train_bak.head())
print('----')
print(x_train.head())

print ('======')
print ('x_test: before / after')
print (x_test_bak.head())
print('---')
print (x_test.head())
# Out:
# x_train: before and after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225         3       1.75           1500    15600
# 7990          3       2.00           1640     7250
# 16579         2       1.00            770     6731
# 6926          3       1.75           1350     8742
# 10340         4       2.50           2370    10631
# ----
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 21225     -0.44      -0.67          -0.67     0.16
# 7990      -0.44      -0.34          -0.52    -0.13
# 16579     -1.58      -1.64          -1.44    -0.15
# 6926      -0.44      -0.67          -0.83    -0.08
# 10340      0.70       0.31           0.25    -0.01
# ======
# x_test: before / after
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925          3       1.75           1350     8742
# 10580         5       3.00           2460     9975
# 13379         3       2.50           2260     5220
# 1132          2       1.50            830     1034
# 20942         5       1.75           2040     8040
# ---
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# /home/ubuntu/apps/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ubuntu/apps/anaconda/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/ubuntu/apps/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/ubuntu/apps/anaconda/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# ## Step 8:  Build a Model
#
# Build a 3 layer network
# - input (64 neurons)
# - hidden (64 neurons)
# - output (1 neuron)

# %%
input_dim = len(input_columns)
print ("input_dim : ", input_dim)
model = tf.keras.Sequential([
                # Input layer.. implicitly defined
                tf.keras.layers.Dense(units=64, activation='relu', input_shape=[input_dim]),
                tf.keras.layers.Dense(units=64, activation='relu'),
                tf.keras.layers.Dense(units=1, activation='linear')
            ])

optimizer = tf.keras.optimizers.RMSprop(0.01)

model.compile(loss='mean_squared_error',
              optimizer=optimizer,
              metrics=['mean_absolute_error', 'mean_squared_error'])

print (model.summary())

tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# input_dim :  4
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,545
# Trainable params: 4,545
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Step 9:  Train

# %%
# %%time

## TODO configure some of these
epochs = 100  ## experiment 100, 500, 1000

print ("training starting ...")
## TODO : to see training output set verbose=2
history = model.fit(x_train, y_train, epochs=epochs)

print ("training done.")
# Out:
# training starting ...
# Train on 21650 samples
# Epoch 1/100
# 21650/21650 [==============================] - 3s 153us/sample - loss: 219936094589.5996 - mean_absolute_error: 344859.4062 - mean_squared_error: 219936030720.0000
# Epoch 2/100
# 21650/21650 [==============================] - 2s 103us/sample - loss: 63971100741.4333 - mean_absolute_error: 153217.6562 - mean_squared_error: 63971078144.0000
# Epoch 3/100
# 21650/21650 [==============================] - 2s 103us/sample - loss: 57979900712.2269 - mean_absolute_error: 143016.0156 - mean_squared_error: 57979932672.0000
# Epoch 4/100
# 21650/21650 [==============================] - 2s 75us/sample - loss: 56485329031.6504 - mean_absolute_error: 140802.1094 - mean_squared_error: 56485330944.0000
# Epoch 5/100
# 21650/21650 [==============================] - 2s 70us/sample - loss: 55549669598.8678 - mean_absolute_error: 139725.7031 - mean_squared_error: 55549628416.0000
# Epoch 6/100
# 21650/21650 [==============================] - 2s 74us/sample - loss: 55132568176.1434 - mean_absolute_error: 138906.5469 - mean_squared_error: 55132614656.0000
# Epoch 7/100
# 21650/21650 [==============================] - 2s 87us/sample - loss: 54830736006.8464 - mean_absolute_error: 138065.5469 - mean_squared_error: 54830755840.0000
# Epoch 8/100
# 21650/21650 [==============================] - 2s 110us/sample - loss: 54560286607.8093 - mean_absolute_error: 137902.8281 - mean_squared_error: 54560264192.0000
# Epoch 9/100
# 21650/21650 [==============================] - 2s 92us/sample - loss: 54354997452.7054 - mean_absolute_error: 137473.1719 - mean_squared_error: 54354993152.0000
# Epoch 10/100
# 21650/21650 [==============================] - 2s 92us/sample - loss: 54239093354.2784 - mean_absolute_error: 137451.2500 - mean_squared_error: 54239100928.0000
# Epoch 11/100
# 21650/21650 [==============================] - 2s 81us/sample - loss: 54059542051.4261 - mean_absolute_error: 137297.3281 - mean_squared_error: 54059515904.0000
# Epoch 12/100
# 21650/21650 [==============================] - 2s 105us/sample - loss: 54115451025.2992 - mean_absolute_error: 136836.9531 - mean_squared_error: 54115442688.0000
# Epoch 13/100
# 21650/21650 [==============================] - 2s 78us/sample - loss: 53999673428.7579 - mean_absolute_error: 136959.7344 - mean_squared_error: 53999677440.0000
# Epoch 14/100
# 21650/21650 [==============================] - 2s 101us/sample - loss: 53952442872.0066 - mean_absolute_error: 137136.2500 - mean_squared_error: 53952425984.0000
# Epoch 15/100
# 21650/21650 [==============================] - 2s 83us/sample - loss: 53900960745.7700 - mean_absolute_error: 136751.1094 - mean_squared_error: 53900984320.0000
# Epoch 16/100
# 21650/21650 [==============================] - 2s 89us/sample - loss: 53900106060.4098 - mean_absolute_error: 136721.6094 - mean_squared_error: 53900148736.0000
# Epoch 17/100
# 21650/21650 [==============================] - 2s 102us/sample - loss: 53870208215.7731 - mean_absolute_error: 136508.3125 - mean_squared_error: 53870247936.0000
# Epoch 18/100
# 21650/21650 [==============================] - 2s 77us/sample - loss: 53846453367.2381 - mean_absolute_error: 136382.3906 - mean_squared_error: 53846446080.0000
# Epoch 19/100
# 21650/21650 [==============================] - 2s 83us/sample - loss: 53815737972.4002 - mean_absolute_error: 136167.3281 - mean_squared_error: 53815746560.0000
# Epoch 20/100
# 21650/21650 [==============================] - 2s 89us/sample - loss: 53733074538.5622 - mean_absolute_error: 135921.8750 - mean_squared_error: 53733089280.0000
# Epoch 21/100
# 21650/21650 [==============================] - 2s 86us/sample - loss: 53771739967.6866 - mean_absolute_error: 136277.3438 - mean_squared_error: 53771739136.0000
# Epoch 22/100
# 21650/21650 [==============================] - 2s 82us/sample - loss: 53770863960.2343 - mean_absolute_error: 135865.4531 - mean_squared_error: 53770862592.0000
# Epoch 23/100
# 21650/21650 [==============================] - 2s 77us/sample - loss: 53647230953.8646 - mean_absolute_error: 136057.2344 - mean_squared_error: 53647278080.0000
# Epoch 24/100
# 21650/21650 [==============================] - 2s 87us/sample - loss: 53694802010.0552 - mean_absolute_error: 135799.2656 - mean_squared_error: 53694828544.0000
# Epoch 25/100
# 21650/21650 [==============================] - 2s 111us/sample - loss: 53660646585.8808 - mean_absolute_error: 135698.1094 - mean_squared_error: 53660631040.0000
# Epoch 26/100
# 21650/21650 [==============================] - 2s 88us/sample - loss: 53592140936.3126 - mean_absolute_error: 135679.1562 - mean_squared_error: 53592129536.0000
# Epoch 27/100
# 21650/21650 [==============================] - 2s 90us/sample - loss: 53535614558.0756 - mean_absolute_error: 135458.9844 - mean_squared_error: 53535608832.0000
# Epoch 28/100
# 21650/21650 [==============================] - 2s 92us/sample - loss: 53590431653.5664 - mean_absolute_error: 135217.2656 - mean_squared_error: 53590392832.0000
# Epoch 29/100
# 21650/21650 [==============================] - 2s 76us/sample - loss: 53563920615.7598 - mean_absolute_error: 135127.7344 - mean_squared_error: 53563908096.0000
# Epoch 30/100
# 21650/21650 [==============================] - 2s 97us/sample - loss: 53432930990.3874 - mean_absolute_error: 135283.1875 - mean_squared_error: 53432922112.0000
# Epoch 31/100
# 21650/21650 [==============================] - 3s 117us/sample - loss: 53341433115.1254 - mean_absolute_error: 135108.9062 - mean_squared_error: 53341421568.0000
# Epoch 32/100
# 21650/21650 [==============================] - 2s 95us/sample - loss: 53448218739.5488 - mean_absolute_error: 134939.8750 - mean_squared_error: 53448232960.0000
# Epoch 33/100
# 21650/21650 [==============================] - 2s 90us/sample - loss: 53269349426.6088 - mean_absolute_error: 135132.0156 - mean_squared_error: 53269381120.0000
# Epoch 34/100
# 21650/21650 [==============================] - 2s 97us/sample - loss: 53283176085.5087 - mean_absolute_error: 134845.8750 - mean_squared_error: 53283205120.0000
# Epoch 35/100
# 21650/21650 [==============================] - 3s 119us/sample - loss: 53283495077.8265 - mean_absolute_error: 134579.0625 - mean_squared_error: 53283520512.0000
# Epoch 36/100
# 21650/21650 [==============================] - 2s 110us/sample - loss: 53223015309.4444 - mean_absolute_error: 134839.9062 - mean_squared_error: 53223043072.0000
# Epoch 37/100
# 21650/21650 [==============================] - 2s 105us/sample - loss: 53186572868.8185 - mean_absolute_error: 134666.6875 - mean_squared_error: 53186572288.0000
# Epoch 38/100
# 21650/21650 [==============================] - 2s 90us/sample - loss: 53119782155.2333 - mean_absolute_error: 134767.4219 - mean_squared_error: 53119819776.0000
# Epoch 39/100
# 21650/21650 [==============================] - 2s 96us/sample - loss: 53103128107.3722 - mean_absolute_error: 134496.4219 - mean_squared_error: 53103165440.0000
# Epoch 40/100
# 21650/21650 [==============================] - 2s 88us/sample - loss: 53204623037.9958 - mean_absolute_error: 134417.0781 - mean_squared_error: 53204615168.0000
# Epoch 41/100
# 21650/21650 [==============================] - 2s 91us/sample - loss: 53138907292.0831 - mean_absolute_error: 134410.0312 - mean_squared_error: 53138935808.0000
# Epoch 42/100
# 21650/21650 [==============================] - 3s 146us/sample - loss: 53092263120.7730 - mean_absolute_error: 134553.5156 - mean_squared_error: 53092274176.0000
# Epoch 43/100
# 21650/21650 [==============================] - 2s 102us/sample - loss: 53141955385.7271 - mean_absolute_error: 134206.6562 - mean_squared_error: 53141954560.0000
# Epoch 44/100
# 21650/21650 [==============================] - 2s 84us/sample - loss: 52991540776.5343 - mean_absolute_error: 134412.1719 - mean_squared_error: 52991569920.0000
# Epoch 45/100
# 21650/21650 [==============================] - 2s 76us/sample - loss: 53019464503.0784 - mean_absolute_error: 134228.4062 - mean_squared_error: 53019443200.0000
# Epoch 46/100
# 21650/21650 [==============================] - 2s 70us/sample - loss: 52998495741.2094 - mean_absolute_error: 134380.1875 - mean_squared_error: 52998496256.0000
# Epoch 47/100
# 21650/21650 [==============================] - 2s 83us/sample - loss: 53043940688.4774 - mean_absolute_error: 134205.0625 - mean_squared_error: 53043970048.0000
# Epoch 48/100
# 21650/21650 [==============================] - 2s 93us/sample - loss: 53020397581.2434 - mean_absolute_error: 134173.4375 - mean_squared_error: 53020381184.0000
# Epoch 49/100
# 21650/21650 [==============================] - 2s 77us/sample - loss: 52887384994.0663 - mean_absolute_error: 134139.6562 - mean_squared_error: 52887384064.0000
# Epoch 50/100
# 21650/21650 [==============================] - 2s 77us/sample - loss: 52886249596.8665 - mean_absolute_error: 134132.4219 - mean_squared_error: 52886241280.0000
# Epoch 51/100
# 21650/21650 [==============================] - 2s 102us/sample - loss: 52950450261.8930 - mean_absolute_error: 134075.3594 - mean_squared_error: 52950466560.0000
# Epoch 52/100
# 21650/21650 [==============================] - 2s 81us/sample - loss: 52736722983.2573 - mean_absolute_error: 134208.7344 - mean_squared_error: 52736729088.0000
# Epoch 53/100
# 21650/21650 [==============================] - 2s 105us/sample - loss: 52885560450.2585 - mean_absolute_error: 134114.8750 - mean_squared_error: 52885540864.0000
# Epoch 54/100
# 21650/21650 [==============================] - 2s 70us/sample - loss: 52919361660.2989 - mean_absolute_error: 133888.2656 - mean_squared_error: 52919328768.0000
# Epoch 55/100
# 21650/21650 [==============================] - 2s 104us/sample - loss: 52801599033.3724 - mean_absolute_error: 133862.6406 - mean_squared_error: 52801568768.0000
# Epoch 56/100
# 21650/21650 [==============================] - 2s 97us/sample - loss: 52841553643.0234 - mean_absolute_error: 133847.4375 - mean_squared_error: 52841570304.0000
# Epoch 57/100
# 21650/21650 [==============================] - 2s 73us/sample - loss: 52722219855.7679 - mean_absolute_error: 133879.4688 - mean_squared_error: 52722200576.0000
# Epoch 58/100
# 21650/21650 [==============================] - 2s 101us/sample - loss: 52796758883.8223 - mean_absolute_error: 133731.9688 - mean_squared_error: 52796760064.0000
# Epoch 59/100
# 21650/21650 [==============================] - 2s 108us/sample - loss: 52794750152.4486 - mean_absolute_error: 133791.3125 - mean_squared_error: 52794769408.0000
# Epoch 60/100
# 21650/21650 [==============================] - 3s 116us/sample - loss: 52831350511.5640 - mean_absolute_error: 133633.5781 - mean_squared_error: 52831322112.0000
# Epoch 61/100
# 21650/21650 [==============================] - 2s 106us/sample - loss: 52824838141.5405 - mean_absolute_error: 133957.4531 - mean_squared_error: 52824829952.0000
# Epoch 62/100
# 21650/21650 [==============================] - 2s 89us/sample - loss: 52789943170.4713 - mean_absolute_error: 133739.2656 - mean_squared_error: 52789960704.0000
# Epoch 63/100
# 21650/21650 [==============================] - 2s 88us/sample - loss: 52661258542.6594 - mean_absolute_error: 133726.7031 - mean_squared_error: 52661260288.0000
# Epoch 64/100
# 21650/21650 [==============================] - 3s 120us/sample - loss: 52835751835.1608 - mean_absolute_error: 133521.0938 - mean_squared_error: 52835766272.0000
# Epoch 65/100
# 21650/21650 [==============================] - 2s 105us/sample - loss: 52695026633.9858 - mean_absolute_error: 133677.9688 - mean_squared_error: 52695003136.0000
# Epoch 66/100
# 21650/21650 [==============================] - 2s 89us/sample - loss: 52716834182.9646 - mean_absolute_error: 133656.2500 - mean_squared_error: 52716818432.0000
# Epoch 67/100
# 21650/21650 [==============================] - 2s 78us/sample - loss: 52702506442.6006 - mean_absolute_error: 133674.1250 - mean_squared_error: 52702498816.0000
# Epoch 68/100
# 21650/21650 [==============================] - 2s 96us/sample - loss: 52627484790.8124 - mean_absolute_error: 133647.4062 - mean_squared_error: 52627476480.0000
# Epoch 69/100
# 21650/21650 [==============================] - 2s 101us/sample - loss: 52624014075.0101 - mean_absolute_error: 133760.4219 - mean_squared_error: 52624007168.0000
# Epoch 70/100
# 21650/21650 [==============================] - 3s 125us/sample - loss: 52606482673.4086 - mean_absolute_error: 133640.2031 - mean_squared_error: 52606500864.0000
# Epoch 71/100
# 21650/21650 [==============================] - 3s 155us/sample - loss: 52674019405.1902 - mean_absolute_error: 133512.7344 - mean_squared_error: 52674027520.0000
# Epoch 72/100
# 21650/21650 [==============================] - 3s 126us/sample - loss: 52558083776.8336 - mean_absolute_error: 133686.8281 - mean_squared_error: 52558118912.0000
# Epoch 73/100
# 21650/21650 [==============================] - 2s 101us/sample - loss: 52645888433.6273 - mean_absolute_error: 133617.4375 - mean_squared_error: 52645904384.0000
# Epoch 74/100
# 21650/21650 [==============================] - 3s 142us/sample - loss: 52744419526.4621 - mean_absolute_error: 133302.6094 - mean_squared_error: 52744392704.0000
# Epoch 75/100
# 21650/21650 [==============================] - 2s 101us/sample - loss: 52693040047.6881 - mean_absolute_error: 133628.8750 - mean_squared_error: 52693061632.0000
# Epoch 76/100
# 21650/21650 [==============================] - 2s 93us/sample - loss: 52701792367.8123 - mean_absolute_error: 133282.2656 - mean_squared_error: 52701777920.0000
# Epoch 77/100
# 21650/21650 [==============================] - 2s 114us/sample - loss: 52701256471.0104 - mean_absolute_error: 133643.5625 - mean_squared_error: 52701233152.0000
# Epoch 78/100
# 21650/21650 [==============================] - 2s 113us/sample - loss: 52545414147.3109 - mean_absolute_error: 133535.6719 - mean_squared_error: 52545458176.0000
# Epoch 79/100
# 21650/21650 [==============================] - 3s 119us/sample - loss: 52655985772.6906 - mean_absolute_error: 133595.3281 - mean_squared_error: 52655984640.0000
# Epoch 80/100
# 21650/21650 [==============================] - 3s 126us/sample - loss: 52568979864.0865 - mean_absolute_error: 133409.7031 - mean_squared_error: 52569010176.0000
# Epoch 81/100
# 21650/21650 [==============================] - 3s 117us/sample - loss: 52524560419.3788 - mean_absolute_error: 133493.6719 - mean_squared_error: 52524523520.0000
# Epoch 82/100
# 21650/21650 [==============================] - 2s 91us/sample - loss: 52537867077.0786 - mean_absolute_error: 133594.7812 - mean_squared_error: 52537888768.0000
# Epoch 83/100
# 21650/21650 [==============================] - 2s 94us/sample - loss: 52594006750.1110 - mean_absolute_error: 133351.0156 - mean_squared_error: 52593987584.0000
# Epoch 84/100
# 21650/21650 [==============================] - 3s 121us/sample - loss: 52537920933.2353 - mean_absolute_error: 133674.7031 - mean_squared_error: 52537884672.0000
# Epoch 85/100
# 21650/21650 [==============================] - 3s 120us/sample - loss: 52540990814.2884 - mean_absolute_error: 133561.8281 - mean_squared_error: 52541001728.0000
# Epoch 86/100
# 21650/21650 [==============================] - 3s 132us/sample - loss: 52565656273.5771 - mean_absolute_error: 133406.7969 - mean_squared_error: 52565651456.0000
# Epoch 87/100
# 21650/21650 [==============================] - 2s 98us/sample - loss: 52580543795.6257 - mean_absolute_error: 133422.3906 - mean_squared_error: 52580511744.0000
# Epoch 88/100
# 21650/21650 [==============================] - 2s 86us/sample - loss: 52502800591.1649 - mean_absolute_error: 133516.3438 - mean_squared_error: 52502814720.0000
# Epoch 89/100
# 21650/21650 [==============================] - 3s 116us/sample - loss: 52497753224.1234 - mean_absolute_error: 133324.0469 - mean_squared_error: 52497772544.0000
# Epoch 90/100
# 21650/21650 [==============================] - 3s 139us/sample - loss: 52474896641.8683 - mean_absolute_error: 133368.6094 - mean_squared_error: 52474908672.0000
# Epoch 91/100
# 21650/21650 [==============================] - 2s 97us/sample - loss: 52562324989.7770 - mean_absolute_error: 133300.8125 - mean_squared_error: 52562341888.0000
# Epoch 92/100
# 21650/21650 [==============================] - 2s 78us/sample - loss: 52516487719.3046 - mean_absolute_error: 133349.9219 - mean_squared_error: 52516503552.0000
# Epoch 93/100
# 21650/21650 [==============================] - 2s 100us/sample - loss: 52515878178.8822 - mean_absolute_error: 133492.1250 - mean_squared_error: 52515889152.0000
# Epoch 94/100
# 21650/21650 [==============================] - 2s 104us/sample - loss: 52496589649.2815 - mean_absolute_error: 133381.2188 - mean_squared_error: 52496572416.0000
# Epoch 95/100
# 21650/21650 [==============================] - 2s 99us/sample - loss: 52477416434.2836 - mean_absolute_error: 133168.0781 - mean_squared_error: 52477440000.0000
# Epoch 96/100
# 21650/21650 [==============================] - 2s 85us/sample - loss: 52455919528.5934 - mean_absolute_error: 133401.3594 - mean_squared_error: 52455956480.0000
# Epoch 97/100
# 21650/21650 [==============================] - 3s 133us/sample - loss: 52530277168.5513 - mean_absolute_error: 133282.6250 - mean_squared_error: 52530270208.0000
# Epoch 98/100
# 21650/21650 [==============================] - 2s 113us/sample - loss: 52347830473.4891 - mean_absolute_error: 133390.9688 - mean_squared_error: 52347822080.0000
# Epoch 99/100
# 21650/21650 [==============================] - 2s 94us/sample - loss: 52522348913.8698 - mean_absolute_error: 133193.5781 - mean_squared_error: 52522360832.0000
# Epoch 100/100
# 21650/21650 [==============================] - 2s 85us/sample - loss: 52353343859.5725 - mean_absolute_error: 133288.5000 - mean_squared_error: 52353351680.0000
# training done.
# CPU times: user 18min 53s, sys: 29min 51s, total: 48min 44s
# Wall time: 3min 34s

# %% [markdown]
# ## Step 10: History

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.history['mean_squared_error'], label='mse')
plt.plot(history.history['mean_absolute_error'], label='mae')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 11 : Evaluate Model

# %%
metric_names = model.metrics_names
print ("model metrics : " , metric_names)
metrics = model.evaluate(x_test, y_test, verbose=0)

for idx, metric in enumerate(metric_names):
    print ("Metric : {} = {:,.2f}".format (metric_names[idx], metrics[idx]))

# print("Testing set - {} : {:,.2f}".format(model.metrics_namesloss))
# print("Testing set Mean Abs Error: {:,.2f}".format(mae))
# print("Testing set Mean Squared Error: {:,.2f}".format(mse))
# Out:
# model metrics :  ['loss', 'mean_absolute_error', 'mean_squared_error']
# Metric : loss = 63,529,597,115.28
# Metric : mean_absolute_error = 132,878.83
# Metric : mean_squared_error = 63,529,586,688.00

# %% [markdown]
# ## Step 12: Predict

# %%
predictions = model.predict(x_test)
print (x_test)
print(predictions)
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 6925      -0.38      -0.61          -0.80    -0.08
# 10580      1.70       0.98           0.39    -0.03
# 13379     -0.38       0.34           0.18    -0.21
# 1132      -1.41      -0.93          -1.35    -0.36
# 20942      1.70      -0.61          -0.06    -0.10
# ...         ...        ...            ...      ...
# 3818       0.66      -0.61          -0.22    -0.22
# 22803     -0.38       0.66           0.61    -0.03
# 20370     -0.38       0.34           0.04    -0.31
# 4536      -0.38       0.34           0.46    -0.26
# 10743      0.66       0.34           1.03    -0.17
#
# [5413 rows x 4 columns]
# [[326430.22]
#  [495356.84]
#  [499646.56]
#  ...
#  [509764.5 ]
#  [598795.56]
#  [667510.6 ]]

# %% [markdown]
# ## Step 13: Evalute prediction output
# Let's do a pd dataframe and do some plots

# %%
predictions_df = pd.DataFrame(x_test_bak)  # use the original one, not scaled
predictions_df['actual_price'] = y_test
predictions_df['predicted_price'] = predictions
predictions_df['error'] = predictions_df['actual_price'] - predictions_df['predicted_price'] 

pd.options.display.float_format = '{:,.2f}'.format
## print sample to see different data every time
predictions_df.sample(frac=0.1)
## or just print the first few
# predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 26590         2       1.75           1850     3060        480000
# 7675          3       2.50           1290     1311        296000
# 14378         4       3.75           3080     4000       1125000
# 9807          3       1.00           1340     5060        329950
# 15859         3       2.50           1920     5910        245000
# ...         ...        ...            ...      ...           ...
# 19653         3       2.50           2090    19598         75000
# 10524         3       2.50           1800     3294        415190
# 15590         2       1.75           1140     5040        345000
# 6856          3       2.50           2010     3087        429500
# 23651         3       1.75           1880    12821        405000
#
#        predicted_price       error
# 26590       507,106.53  -27,106.53
# 7675        367,523.78  -71,523.78
# 14378       802,794.38  322,205.62
# 9807        368,219.59  -38,269.59
# 15859       412,350.59 -167,350.59
# ...                ...         ...
# 19653       457,101.91 -382,101.91
# 10524       419,942.78   -4,752.78
# 15590       329,740.91   15,259.09
# 6856        470,043.28  -40,543.28
# 23651       433,879.34  -28,879.34
#
# [541 rows x 7 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist (predictions_df['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## In the previous plot, outliers are skewing the results
## let's filter out the outliers.
## only consider predictions where the error is less than 100k (chosen randomly)

# %matplotlib inline
import matplotlib.pyplot as plt

predictions_df_filtered = predictions_df[predictions_df['error'].abs() < 100000]

plt.hist (predictions_df_filtered['error'], bins=10, rwidth=0.8)
plt.xlabel("Prediction Error [$]")
_ = plt.ylabel("Count")

# %%
## which house we got really wrong?
print ("biggest error : ")
predictions_df.loc[predictions_df['error'].abs().idxmax()]
# Out:
# biggest error :
# Bedrooms                   6.00
# Bathrooms                  6.50
# SqFtTotLiving          7,560.00
# SqFtLot               44,000.00
# actual_price      11,000,000.00
# predicted_price    2,542,243.00
# error              8,457,757.00
# Name: 20114, dtype: float64

# %%
## which house we are spot on?
print ("lowest error")
predictions_df.loc[predictions_df['error'].abs().idxmin()]
# Out:
# lowest error
# Bedrooms                4.00
# Bathrooms               2.75
# SqFtTotLiving       3,150.00
# SqFtLot             5,905.00
# actual_price      720,990.00
# predicted_price   720,929.94
# error                  60.06
# Name: 7982, dtype: float64

# %% [markdown]
# ### How many house sales, we predicted within 5% ?
# Let's use 5% margin of error as our benchmark

# %%
predictions_df['error_percentage'] = predictions_df['error'].abs() * 100 / predictions_df['actual_price']
predictions_df
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 6925          3       1.75           1350     8742        373300
# 10580         5       3.00           2460     9975        450000
# 13379         3       2.50           2260     5220        485000
# 1132          2       1.50            830     1034        219950
# 20942         5       1.75           2040     8040        310000
# ...         ...        ...            ...      ...           ...
# 3818          4       1.75           1890     4800        489200
# 22803         3       2.75           2660    10004        450000
# 20370         3       2.50           2130     2520        567000
# 4536          3       2.50           2520     3750        735000
# 10743         4       2.50           3060     6272        504000
#
#        predicted_price       error  error_percentage
# 6925        326,430.22   46,869.78             12.56
# 10580       495,356.84  -45,356.84             10.08
# 13379       499,646.56  -14,646.56              3.02
# 1132        333,161.09 -113,211.09             51.47
# 20942       440,576.09 -130,576.09             42.12
# ...                ...         ...               ...
# 3818        462,322.28   26,877.72              5.49
# 22803       643,262.06 -193,262.06             42.95
# 20370       509,764.50   57,235.50             10.09
# 4536        598,795.56  136,204.44             18.53
# 10743       667,510.62 -163,510.62             32.44
#
# [5413 rows x 8 columns]

# %%
benchmark = 5  # 5%

good_predictions = predictions_df[predictions_df['error_percentage'] <= benchmark]

good_predictions
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot  actual_price  \
# 13379         3       2.50           2260     5220        485000
# 23559         5       2.25           3070    11475        635000
# 9894          4       1.00           1130     4000        365000
# 21054         3       2.50           1680    11560        350000
# 23789         2       2.00           1300     2983        400749
# ...         ...        ...            ...      ...           ...
# 24039         3       2.50           2720     7969        645000
# 8562          2       1.50            980     1425        369950
# 8555          3       2.25           1980     2375        484940
# 121           3       1.50           1810     6550        425000
# 2092          2       1.50            910      976        346000
#
#        predicted_price      error  error_percentage
# 13379       499,646.56 -14,646.56              3.02
# 23559       618,688.94  16,311.06              2.57
# 9894        347,347.72  17,652.28              4.84
# 21054       360,968.66 -10,968.66              3.13
# 23789       386,909.81  13,839.19              3.45
# ...                ...        ...               ...
# 24039       640,675.69   4,324.31              0.67
# 8562        353,735.59  16,214.41              4.38
# 8555        493,072.88  -8,132.88              1.68
# 121         428,389.66  -3,389.66              0.80
# 2092        347,789.16  -1,789.16              0.52
#
# [700 rows x 8 columns]

# %%
meeting_benchmark = good_predictions.shape[0] *100 / predictions_df.shape[0]

print ("number of predictions within benchmark error ({}%) are  =  {:,}  ({:.1f}% of total)".
       format (benchmark, good_predictions.shape[0], meeting_benchmark))
# Out:
# number of predictions within benchmark error (5%) are  =  700  (12.9% of total)

# %% [markdown]
# ## Step 14: Ideas to Try
# Now that we had done an 'end-to-end' regression implementation, lets tune our algorithm.
#
# **==> Q : What are some fo the things we can do to get a higher performance?**
#
# Here are some ideas to get you started
# - **Idea 1 : Any other inputs we can add?**
#   - In Step 5, add a couple more columns as input
#   - only choose numeric columns at this time
#   - Try adding 'LandVal'  as an input column.  Run again, did that improve the benchmark performance?
#   - What would be the implication of adding all the columns?
#
# - **Idea 2 : Remove outliers**
# As you noticed, we have quite a bit of outliers (remember the 33 bedroom house? :-).  Outliers tend to skew the results.  So let's remove them
#   - Step 4 : uncomment the cell.  Here we are filtering only houses that have less than 5 bedrooms
#
# - **Idea 3 : Increase epochs**
#   - In Step 10, increase epochs from 100 to 500 to 1000
#   - Notice the training time will increase
#   - do you get better results?  why or why not?
#
# - **Idea 4 : Build a Bigger network**
#   - In Step 8, we are setting up our network.  We are using 64 neurons
#   - Increase the number of neurons from 64 to 128
#   - Th
#   - Does the training time go up?
#   - Are you getting better accuracy?
#   - We can also add more layers and build a 'deeper' network.  More on this later
#
# - **Idea 5 : Need more data :-)**
# Most of the time, neural networks can yield better results if trained on more data
#
# - **Any other ideas?**
#
# #### Share your experiments with the class!
#
# **What is the best score you have gotten? :-)**

# %% [markdown]
# ## Final Step : Create the most compact code
# In this notebook we walked you through multiple steps for learning purposes.
# Now we are asking you to come up with **bare minimum** code to implement this neural net.
#
# ### Class Challenge :-)
# - Let's see who can come up with most compact code (fewest lines)
# - Create a new notebook, and start from scratch
# - Few hints
#   - no prints
#   - minimize comments
#   - no debug / exploration
#
# **Ready, set, go!**
#
# ### Our Answer
# [minimal solution file](2.5-regression-house-prices-minimal.ipynb)
